# %%
# 导入必要的库
import torch
import torch.nn as nn
import numpy as np
import torch.optim as optim
from torchvision import transforms, datasets, models, utils
from torchsummary import summary # 可视化训练过程
from torch.utils.data import DataLoader
import time
import matplotlib.pyplot as plt
import os
import seaborn as sns
import pandas as pd
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
from PIL import Image

# %%
# 分为为train, val, test定义transform
image_transforms = {
    'train' : transforms.Compose([
        transforms.RandomResizedCrop(size=300, scale=(0.8, 1.1)), #功能：随机长宽比裁剪原始图片, 表示随机crop出来的图片会在的0.08倍至1.1倍之间
        transforms.RandomRotation(degrees=10), #功能：根据degrees随机旋转一定角度, 则表示在（-10，+10）度之间随机旋转
        transforms.ColorJitter(0.4, 0.4, 0.4), #功能：修改亮度、对比度和饱和度
        transforms.RandomHorizontalFlip(), #功能：水平翻转
        transforms.CenterCrop(size=256), #功能：根据给定的size从中心裁剪，size - 若为sequence,则为(h,w)，若为int，则(size,size)
        transforms.ToTensor(), #numpy --> tensor
        # 功能：对数据按通道进行标准化（RGB），即先减均值，再除以标准差
        transforms.Normalize([0.485, 0.456, 0.406],# mean
                             [0.229, 0.224, 0.225])# std 
    ]),
    
    'val' : transforms.Compose([
        transforms.Resize(300),
        transforms.CenterCrop(256),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],# mean
                             [0.229, 0.224, 0.225])# std 
    ]),
    
    'test' : transforms.Compose([
        transforms.Resize(300),
        transforms.CenterCrop(256),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],# mean
                             [0.229, 0.224, 0.225])# std 
    ])
}

# %%
# 加载数据集

# 数据集所在目录路径
data_dir = 'normalViralANDbacCovid/'
# train路径
train_dir = data_dir + 'train/'
# val路径
val_dir = data_dir + 'val/'
# test路径
test_dir = data_dir + 'test/'

# 从文件中读取数据
datasets = {
    'train' : datasets.ImageFolder(train_dir, transform=image_transforms['train']), # 读取train中的数据集，并transform
    'val' : datasets.ImageFolder(val_dir, transform=image_transforms['val']),  # 读取val中的数据集，并transform
    'test' : datasets.ImageFolder(test_dir, transform=image_transforms['test']) #  读取test中的数据集，并transform
}

# 定义BATCH_SIZE
BATCH_SIZE = 128 # 每批读取128张图片

# DataLoader : 创建iterator, 按批读取数据
dataloaders = {
    'train' : DataLoader(datasets['train'], batch_size=BATCH_SIZE, shuffle=True), # 训练集
    'val' : DataLoader(datasets['val'], batch_size=BATCH_SIZE, shuffle=True), # 验证集
    'test' : DataLoader(datasets['test'], batch_size=BATCH_SIZE, shuffle=True) # 测试集
}

# 创建label的键值对
LABEL = dict((v, k) for k, v in datasets['train'].class_to_idx.items())

LABEL
# Out:
# {0: 'bacCovid', 1: 'normalViral'}

# %%
# train 简介
dataloaders['train'].dataset
# Out:
# Dataset ImageFolder
#     Number of datapoints: 12535
#     Root location: normalViralANDbacCovid/train/
#     StandardTransform
# Transform: Compose(
#                RandomResizedCrop(size=(300, 300), scale=(0.8, 1.1), ratio=(0.75, 1.3333), interpolation=bilinear), antialias=None)
#                RandomRotation(degrees=[-10.0, 10.0], interpolation=nearest, expand=False, fill=0)
#                ColorJitter(brightness=[0.6, 1.4], contrast=[0.6, 1.4], saturation=[0.6, 1.4], hue=None)
#                RandomHorizontalFlip(p=0.5)
#                CenterCrop(size=(256, 256))
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %%
dataloaders['train'].dataset.classes # train下的类别
# Out:
# ['bacCovid', 'normalViral']

# %%
dataloaders['train'].dataset.root # train的路径
# Out:
# 'normalViralANDbacCovid/train/'

# %%
# 肺部细菌感染的图片
files_bacCovid_pneumonia = os.listdir(os.path.join(str(dataloaders['train'].dataset.root), 'bacCovid'))
files_bacCovid_pneumonia
# Out:
# ['Bacteria (1).jpeg',
#  'Bacteria (10).jpeg',
#  'Bacteria (100).jpeg',
#  'Bacteria (1000).jpeg',
#  'Bacteria (1001).jpeg',
#  'Bacteria (1002).jpeg',
#  'Bacteria (1003).jpeg',
#  'Bacteria (1004).jpeg',
#  'Bacteria (1005).jpeg',
#  'Bacteria (1006).jpeg',
#  'Bacteria (1007).jpeg',
#  'Bacteria (1008).jpeg',
#  'Bacteria (1009).jpeg',
#  'Bacteria (101).jpeg',
#  'Bacteria (1010).jpeg',
#  'Bacteria (1011).jpeg',
#  'Bacteria (1012).jpeg',
#  'Bacteria (1013).jpeg',
#  'Bacteria (1014).jpeg',
#  'Bacteria (1015).jpeg',
#  'Bacteria (1016).jpeg',
#  'Bacteria (1017).jpeg',
#  'Bacteria (1018).jpeg',
#  'Bacteria (1019).jpeg',
#  'Bacteria (102).jpeg',
#  'Bacteria (1020).jpeg',
#  'Bacteria (1021).jpeg',
#  'Bacteria (1022).jpeg',
#  'Bacteria (1023).jpeg',
#  'Bacteria (1024).jpeg',
#  'Bacteria (1025).jpeg',
#  'Bacteria (1026).jpeg',
#  'Bacteria (1027).jpeg',
#  'Bacteria (1028).jpeg',
#  'Bacteria (1029).jpeg',
#  'Bacteria (103).jpeg',
#  'Bacteria (1030).jpeg',
#  'Bacteria (1031).jpeg',
#  'Bacteria (1032).jpeg',
#  'Bacteria (1033).jpeg',
#  'Bacteria (1034).jpeg',
#  'Bacteria (1035).jpeg',
#  'Bacteria (1036).jpeg',
#  'Bacteria (1037).jpeg',
#  'Bacteria (1038).jpeg',
#  'Bacteria (1039).jpeg',
#  'Bacteria (104).jpeg',
#  'Bacteria (1040).jpeg',
#  'Bacteria (1041).jpeg',
#  'Bacteria (1042).jpeg',
#  'Bacteria (1043).jpeg',
#  'Bacteria (1044).jpeg',
#  'Bacteria (1045).jpeg',
#  'Bacteria (1046).jpeg',
#  'Bacteria (1047).jpeg',
#  'Bacteria (1048).jpeg',
#  'Bacteria (1049).jpeg',
#  'Bacteria (105).jpeg',
#  'Bacteria (1050).jpeg',
#  'Bacteria (1051).jpeg',
#  'Bacteria (1052).jpeg',
#  'Bacteria (1053).jpeg',
#  'Bacteria (1054).jpeg',
#  'Bacteria (1055).jpeg',
#  'Bacteria (1056).jpeg',
#  'Bacteria (1057).jpeg',
#  'Bacteria (1058).jpeg',
#  'Bacteria (1059).jpeg',
#  'Bacteria (106).jpeg',
#  'Bacteria (1060).jpeg',
#  'Bacteria (1061).jpeg',
#  'Bacteria (1062).jpeg',
#  'Bacteria (1063).jpeg',
#  'Bacteria (1064).jpeg',
#  'Bacteria (1065).jpeg',
#  'Bacteria (1066).jpeg',
#  'Bacteria (1067).jpeg',
#  'Bacteria (1068).jpeg',
#  'Bacteria (1069).jpeg',
#  'Bacteria (107).jpeg',
#  'Bacteria (1070).jpeg',
#  'Bacteria (1071).jpeg',
#  'Bacteria (1072).jpeg',
#  'Bacteria (1073).jpeg',
#  'Bacteria (1074).jpeg',
#  'Bacteria (1075).jpeg',
#  'Bacteria (1076).jpeg',
#  'Bacteria (1077).jpeg',
#  'Bacteria (1078).jpeg',
#  'Bacteria (1079).jpeg',
#  'Bacteria (108).jpeg',
#  'Bacteria (1080).jpeg',
#  'Bacteria (1081).jpeg',
#  'Bacteria (1082).jpeg',
#  'Bacteria (1083).jpeg',
#  'Bacteria (1084).jpeg',
#  'Bacteria (1085).jpeg',
#  'Bacteria (1086).jpeg',
#  'Bacteria (1087).jpeg',
#  'Bacteria (1088).jpeg',
#  'Bacteria (1089).jpeg',
#  'Bacteria (109).jpeg',
#  'Bacteria (1090).jpeg',
#  'Bacteria (1091).jpeg',
#  'Bacteria (1092).jpeg',
#  'Bacteria (1093).jpeg',
#  'Bacteria (1094).jpeg',
#  'Bacteria (1095).jpeg',
#  'Bacteria (1096).jpeg',
#  'Bacteria (1097).jpeg',
#  'Bacteria (1098).jpeg',
#  'Bacteria (1099).jpeg',
#  'Bacteria (11).jpeg',
#  'Bacteria (110).jpeg',
#  'Bacteria (1100).jpeg',
#  'Bacteria (1101).jpeg',
#  'Bacteria (1102).jpeg',
#  'Bacteria (1103).jpeg',
#  'Bacteria (1104).jpeg',
#  'Bacteria (1105).jpeg',
#  'Bacteria (1106).jpeg',
#  'Bacteria (1107).jpeg',
#  'Bacteria (1108).jpeg',
#  'Bacteria (1109).jpeg',
#  'Bacteria (111).jpeg',
#  'Bacteria (1110).jpeg',
#  'Bacteria (1111).jpeg',
#  'Bacteria (1112).jpeg',
#  'Bacteria (1113).jpeg',
#  'Bacteria (1114).jpeg',
#  'Bacteria (1115).jpeg',
#  'Bacteria (1116).jpeg',
#  'Bacteria (1117).jpeg',
#  'Bacteria (1118).jpeg',
#  'Bacteria (1119).jpeg',
#  'Bacteria (112).jpeg',
#  'Bacteria (1120).jpeg',
#  'Bacteria (1121).jpeg',
#  'Bacteria (1122).jpeg',
#  'Bacteria (1123).jpeg',
#  'Bacteria (1124).jpeg',
#  'Bacteria (1125).jpeg',
#  'Bacteria (1126).jpeg',
#  'Bacteria (1127).jpeg',
#  'Bacteria (1128).jpeg',
#  'Bacteria (1129).jpeg',
#  'Bacteria (113).jpeg',
#  'Bacteria (1130).jpeg',
#  'Bacteria (1131).jpeg',
#  'Bacteria (1132).jpeg',
#  'Bacteria (1133).jpeg',
#  'Bacteria (1134).jpeg',
#  'Bacteria (1135).jpeg',
#  'Bacteria (1136).jpeg',
#  'Bacteria (1137).jpeg',
#  'Bacteria (1138).jpeg',
#  'Bacteria (1139).jpeg',
#  'Bacteria (114).jpeg',
#  'Bacteria (1140).jpeg',
#  'Bacteria (1141).jpeg',
#  'Bacteria (1142).jpeg',
#  'Bacteria (1143).jpeg',
#  'Bacteria (1144).jpeg',
#  'Bacteria (1145).jpeg',
#  'Bacteria (1146).jpeg',
#  'Bacteria (1147).jpeg',
#  'Bacteria (1148).jpeg',
#  'Bacteria (1149).jpeg',
#  'Bacteria (115).jpeg',
#  'Bacteria (1150).jpeg',
#  'Bacteria (1151).jpeg',
#  'Bacteria (1152).jpeg',
#  'Bacteria (1153).jpeg',
#  'Bacteria (1154).jpeg',
#  'Bacteria (1155).jpeg',
#  'Bacteria (1156).jpeg',
#  'Bacteria (1157).jpeg',
#  'Bacteria (1158).jpeg',
#  'Bacteria (1159).jpeg',
#  'Bacteria (116).jpeg',
#  'Bacteria (1160).jpeg',
#  'Bacteria (1161).jpeg',
#  'Bacteria (1162).jpeg',
#  'Bacteria (1163).jpeg',
#  'Bacteria (1164).jpeg',
#  'Bacteria (1165).jpeg',
#  'Bacteria (1166).jpeg',
#  'Bacteria (1167).jpeg',
#  'Bacteria (1168).jpeg',
#  'Bacteria (1169).jpeg',
#  'Bacteria (117).jpeg',
#  'Bacteria (1170).jpeg',
#  'Bacteria (1171).jpeg',
#  'Bacteria (1172).jpeg',
#  'Bacteria (1173).jpeg',
#  'Bacteria (1174).jpeg',
#  'Bacteria (1175).jpeg',
#  'Bacteria (1176).jpeg',
#  'Bacteria (1177).jpeg',
#  'Bacteria (1178).jpeg',
#  'Bacteria (1179).jpeg',
#  'Bacteria (118).jpeg',
#  'Bacteria (1180).jpeg',
#  'Bacteria (1181).jpeg',
#  'Bacteria (1182).jpeg',
#  'Bacteria (1183).jpeg',
#  'Bacteria (1184).jpeg',
#  'Bacteria (1185).jpeg',
#  'Bacteria (1186).jpeg',
#  'Bacteria (1187).jpeg',
#  'Bacteria (1188).jpeg',
#  'Bacteria (1189).jpeg',
#  'Bacteria (119).jpeg',
#  'Bacteria (1190).jpeg',
#  'Bacteria (1191).jpeg',
#  'Bacteria (1192).jpeg',
#  'Bacteria (1193).jpeg',
#  'Bacteria (1194).jpeg',
#  'Bacteria (1195).jpeg',
#  'Bacteria (1196).jpeg',
#  'Bacteria (1197).jpeg',
#  'Bacteria (1198).jpeg',
#  'Bacteria (1199).jpeg',
#  'Bacteria (12).jpeg',
#  'Bacteria (120).jpeg',
#  'Bacteria (1200).jpeg',
#  'Bacteria (1201).jpeg',
#  'Bacteria (1202).jpeg',
#  'Bacteria (1203).jpeg',
#  'Bacteria (1204).jpeg',
#  'Bacteria (1205).jpeg',
#  'Bacteria (1206).jpeg',
#  'Bacteria (1207).jpeg',
#  'Bacteria (1208).jpeg',
#  'Bacteria (1209).jpeg',
#  'Bacteria (121).jpeg',
#  'Bacteria (1210).jpeg',
#  'Bacteria (1211).jpeg',
#  'Bacteria (1212).jpeg',
#  'Bacteria (1213).jpeg',
#  'Bacteria (1214).jpeg',
#  'Bacteria (1215).jpeg',
#  'Bacteria (1216).jpeg',
#  'Bacteria (1217).jpeg',
#  'Bacteria (1218).jpeg',
#  'Bacteria (1219).jpeg',
#  'Bacteria (122).jpeg',
#  'Bacteria (1220).jpeg',
#  'Bacteria (1221).jpeg',
#  'Bacteria (1222).jpeg',
#  'Bacteria (1223).jpeg',
#  'Bacteria (1224).jpeg',
#  'Bacteria (1225).jpeg',
#  'Bacteria (1226).jpeg',
#  'Bacteria (1227).jpeg',
#  'Bacteria (1228).jpeg',
#  'Bacteria (1229).jpeg',
#  'Bacteria (123).jpeg',
#  'Bacteria (1230).jpeg',
#  'Bacteria (1231).jpeg',
#  'Bacteria (1232).jpeg',
#  'Bacteria (1233).jpeg',
#  'Bacteria (1234).jpeg',
#  'Bacteria (1235).jpeg',
#  'Bacteria (1236).jpeg',
#  'Bacteria (1237).jpeg',
#  'Bacteria (1238).jpeg',
#  'Bacteria (1239).jpeg',
#  'Bacteria (124).jpeg',
#  'Bacteria (1240).jpeg',
#  'Bacteria (1241).jpeg',
#  'Bacteria (1242).jpeg',
#  'Bacteria (1243).jpeg',
#  'Bacteria (1244).jpeg',
#  'Bacteria (1245).jpeg',
#  'Bacteria (1246).jpeg',
#  'Bacteria (1247).jpeg',
#  'Bacteria (1248).jpeg',
#  'Bacteria (1249).jpeg',
#  'Bacteria (125).jpeg',
#  'Bacteria (1250).jpeg',
#  'Bacteria (1251).jpeg',
#  'Bacteria (1252).jpeg',
#  'Bacteria (1253).jpeg',
#  'Bacteria (1254).jpeg',
#  'Bacteria (1255).jpeg',
#  'Bacteria (1256).jpeg',
#  'Bacteria (1257).jpeg',
#  'Bacteria (1258).jpeg',
#  'Bacteria (1259).jpeg',
#  'Bacteria (126).jpeg',
#  'Bacteria (1260).jpeg',
#  'Bacteria (1261).jpeg',
#  'Bacteria (1262).jpeg',
#  'Bacteria (1263).jpeg',
#  'Bacteria (1264).jpeg',
#  'Bacteria (1265).jpeg',
#  'Bacteria (1266).jpeg',
#  'Bacteria (1267).jpeg',
#  'Bacteria (1268).jpeg',
#  'Bacteria (1269).jpeg',
#  'Bacteria (127).jpeg',
#  'Bacteria (1270).jpeg',
#  'Bacteria (1271).jpeg',
#  'Bacteria (1272).jpeg',
#  'Bacteria (1273).jpeg',
#  'Bacteria (1274).jpeg',
#  'Bacteria (1275).jpeg',
#  'Bacteria (1276).jpeg',
#  'Bacteria (1277).jpeg',
#  'Bacteria (1278).jpeg',
#  'Bacteria (1279).jpeg',
#  'Bacteria (128).jpeg',
#  'Bacteria (1280).jpeg',
#  'Bacteria (1281).jpeg',
#  'Bacteria (1282).jpeg',
#  'Bacteria (1283).jpeg',
#  'Bacteria (1284).jpeg',
#  'Bacteria (1285).jpeg',
#  'Bacteria (1286).jpeg',
#  'Bacteria (1287).jpeg',
#  'Bacteria (1288).jpeg',
#  'Bacteria (1289).jpeg',
#  'Bacteria (129).jpeg',
#  'Bacteria (1290).jpeg',
#  'Bacteria (1291).jpeg',
#  'Bacteria (1292).jpeg',
#  'Bacteria (1293).jpeg',
#  'Bacteria (1294).jpeg',
#  'Bacteria (1295).jpeg',
#  'Bacteria (1296).jpeg',
#  'Bacteria (1297).jpeg',
#  'Bacteria (1298).jpeg',
#  'Bacteria (1299).jpeg',
#  'Bacteria (13).jpeg',
#  'Bacteria (130).jpeg',
#  'Bacteria (1300).jpeg',
#  'Bacteria (1301).jpeg',
#  'Bacteria (1302).jpeg',
#  'Bacteria (1303).jpeg',
#  'Bacteria (1304).jpeg',
#  'Bacteria (1305).jpeg',
#  'Bacteria (1306).jpeg',
#  'Bacteria (1307).jpeg',
#  'Bacteria (1308).jpeg',
#  'Bacteria (1309).jpeg',
#  'Bacteria (131).jpeg',
#  'Bacteria (1310).jpeg',
#  'Bacteria (1311).jpeg',
#  'Bacteria (1312).jpeg',
#  'Bacteria (1313).jpeg',
#  'Bacteria (1314).jpeg',
#  'Bacteria (1315).jpeg',
#  'Bacteria (1316).jpeg',
#  'Bacteria (1317).jpeg',
#  'Bacteria (1318).jpeg',
#  'Bacteria (1319).jpeg',
#  'Bacteria (132).jpeg',
#  'Bacteria (1320).jpeg',
#  'Bacteria (1321).jpeg',
#  'Bacteria (1322).jpeg',
#  'Bacteria (1323).jpeg',
#  'Bacteria (1324).jpeg',
#  'Bacteria (1325).jpeg',
#  'Bacteria (1326).jpeg',
#  'Bacteria (1327).jpeg',
#  'Bacteria (1328).jpeg',
#  'Bacteria (1329).jpeg',
#  'Bacteria (133).jpeg',
#  'Bacteria (1330).jpeg',
#  'Bacteria (1331).jpeg',
#  'Bacteria (1332).jpeg',
#  'Bacteria (1333).jpeg',
#  'Bacteria (1334).jpeg',
#  'Bacteria (1335).jpeg',
#  'Bacteria (1336).jpeg',
#  'Bacteria (1337).jpeg',
#  'Bacteria (1338).jpeg',
#  'Bacteria (1339).jpeg',
#  'Bacteria (134).jpeg',
#  'Bacteria (1340).jpeg',
#  'Bacteria (1341).jpeg',
#  'Bacteria (1342).jpeg',
#  'Bacteria (1343).jpeg',
#  'Bacteria (1344).jpeg',
#  'Bacteria (1345).jpeg',
#  'Bacteria (1346).jpeg',
#  'Bacteria (1347).jpeg',
#  'Bacteria (1348).jpeg',
#  'Bacteria (1349).jpeg',
#  'Bacteria (135).jpeg',
#  'Bacteria (1350).jpeg',
#  'Bacteria (1351).jpeg',
#  'Bacteria (1352).jpeg',
#  'Bacteria (1353).jpeg',
#  'Bacteria (1354).jpeg',
#  'Bacteria (1355).jpeg',
#  'Bacteria (1356).jpeg',
#  'Bacteria (1357).jpeg',
#  'Bacteria (1358).jpeg',
#  'Bacteria (1359).jpeg',
#  'Bacteria (136).jpeg',
#  'Bacteria (1360).jpeg',
#  'Bacteria (1361).jpeg',
#  'Bacteria (1362).jpeg',
#  'Bacteria (1363).jpeg',
#  'Bacteria (1364).jpeg',
#  'Bacteria (1365).jpeg',
#  'Bacteria (1366).jpeg',
#  'Bacteria (1367).jpeg',
#  'Bacteria (1368).jpeg',
#  'Bacteria (1369).jpeg',
#  'Bacteria (137).jpeg',
#  'Bacteria (1370).jpeg',
#  'Bacteria (1371).jpeg',
#  'Bacteria (1372).jpeg',
#  'Bacteria (1373).jpeg',
#  'Bacteria (1374).jpeg',
#  'Bacteria (1375).jpeg',
#  'Bacteria (1376).jpeg',
#  'Bacteria (1377).jpeg',
#  'Bacteria (1378).jpeg',
#  'Bacteria (1379).jpeg',
#  'Bacteria (138).jpeg',
#  'Bacteria (1380).jpeg',
#  'Bacteria (1381).jpeg',
#  'Bacteria (1382).jpeg',
#  'Bacteria (1383).jpeg',
#  'Bacteria (1384).jpeg',
#  'Bacteria (1385).jpeg',
#  'Bacteria (1386).jpeg',
#  'Bacteria (1387).jpeg',
#  'Bacteria (1388).jpeg',
#  'Bacteria (1389).jpeg',
#  'Bacteria (139).jpeg',
#  'Bacteria (1390).jpeg',
#  'Bacteria (1391).jpeg',
#  'Bacteria (1392).jpeg',
#  'Bacteria (1393).jpeg',
#  'Bacteria (1394).jpeg',
#  'Bacteria (1395).jpeg',
#  'Bacteria (1396).jpeg',
#  'Bacteria (1397).jpeg',
#  'Bacteria (1398).jpeg',
#  'Bacteria (1399).jpeg',
#  'Bacteria (14).jpeg',
#  'Bacteria (140).jpeg',
#  'Bacteria (1400).jpeg',
#  'Bacteria (1401).jpeg',
#  'Bacteria (1402).jpeg',
#  'Bacteria (1403).jpeg',
#  'Bacteria (1404).jpeg',
#  'Bacteria (1405).jpeg',
#  'Bacteria (1406).jpeg',
#  'Bacteria (1407).jpeg',
#  'Bacteria (1408).jpeg',
#  'Bacteria (1409).jpeg',
#  'Bacteria (141).jpeg',
#  'Bacteria (1410).jpeg',
#  'Bacteria (1411).jpeg',
#  'Bacteria (1412).jpeg',
#  'Bacteria (1413).jpeg',
#  'Bacteria (1414).jpeg',
#  'Bacteria (1415).jpeg',
#  'Bacteria (1416).jpeg',
#  'Bacteria (1417).jpeg',
#  'Bacteria (1418).jpeg',
#  'Bacteria (1419).jpeg',
#  'Bacteria (142).jpeg',
#  'Bacteria (1420).jpeg',
#  'Bacteria (1421).jpeg',
#  'Bacteria (1422).jpeg',
#  'Bacteria (1423).jpeg',
#  'Bacteria (1424).jpeg',
#  'Bacteria (1425).jpeg',
#  'Bacteria (1426).jpeg',
#  'Bacteria (1427).jpeg',
#  'Bacteria (1428).jpeg',
#  'Bacteria (1429).jpeg',
#  'Bacteria (143).jpeg',
#  'Bacteria (1430).jpeg',
#  'Bacteria (1431).jpeg',
#  'Bacteria (1432).jpeg',
#  'Bacteria (1433).jpeg',
#  'Bacteria (1434).jpeg',
#  'Bacteria (1435).jpeg',
#  'Bacteria (1436).jpeg',
#  'Bacteria (1437).jpeg',
#  'Bacteria (1438).jpeg',
#  'Bacteria (1439).jpeg',
#  'Bacteria (144).jpeg',
#  'Bacteria (1440).jpeg',
#  'Bacteria (1441).jpeg',
#  'Bacteria (1442).jpeg',
#  'Bacteria (1443).jpeg',
#  'Bacteria (1444).jpeg',
#  'Bacteria (1445).jpeg',
#  'Bacteria (1446).jpeg',
#  'Bacteria (1447).jpeg',
#  'Bacteria (1448).jpeg',
#  'Bacteria (1449).jpeg',
#  'Bacteria (145).jpeg',
#  'Bacteria (1450).jpeg',
#  'Bacteria (1451).jpeg',
#  'Bacteria (1452).jpeg',
#  'Bacteria (1453).jpeg',
#  'Bacteria (1454).jpeg',
#  'Bacteria (1455).jpeg',
#  'Bacteria (1456).jpeg',
#  'Bacteria (1457).jpeg',
#  'Bacteria (1458).jpeg',
#  'Bacteria (1459).jpeg',
#  'Bacteria (146).jpeg',
#  'Bacteria (1460).jpeg',
#  'Bacteria (1461).jpeg',
#  'Bacteria (1462).jpeg',
#  'Bacteria (1463).jpeg',
#  'Bacteria (1464).jpeg',
#  'Bacteria (1465).jpeg',
#  'Bacteria (1466).jpeg',
#  'Bacteria (1467).jpeg',
#  'Bacteria (1468).jpeg',
#  'Bacteria (1469).jpeg',
#  'Bacteria (147).jpeg',
#  'Bacteria (1470).jpeg',
#  'Bacteria (1471).jpeg',
#  'Bacteria (1472).jpeg',
#  'Bacteria (1473).jpeg',
#  'Bacteria (1474).jpeg',
#  'Bacteria (1475).jpeg',
#  'Bacteria (1476).jpeg',
#  'Bacteria (1477).jpeg',
#  'Bacteria (1478).jpeg',
#  'Bacteria (1479).jpeg',
#  'Bacteria (148).jpeg',
#  'Bacteria (1480).jpeg',
#  'Bacteria (1481).jpeg',
#  'Bacteria (1482).jpeg',
#  'Bacteria (1483).jpeg',
#  'Bacteria (1484).jpeg',
#  'Bacteria (1485).jpeg',
#  'Bacteria (1486).jpeg',
#  'Bacteria (1487).jpeg',
#  'Bacteria (1488).jpeg',
#  'Bacteria (1489).jpeg',
#  'Bacteria (149).jpeg',
#  'Bacteria (1490).jpeg',
#  'Bacteria (1491).jpeg',
#  'Bacteria (1492).jpeg',
#  'Bacteria (1493).jpeg',
#  'Bacteria (1494).jpeg',
#  'Bacteria (1495).jpeg',
#  'Bacteria (1496).jpeg',
#  'Bacteria (1497).jpeg',
#  'Bacteria (1498).jpeg',
#  'Bacteria (1499).jpeg',
#  'Bacteria (15).jpeg',
#  'Bacteria (150).jpeg',
#  'Bacteria (1500).jpeg',
#  'Bacteria (1501).jpeg',
#  'Bacteria (1502).jpeg',
#  'Bacteria (1503).jpeg',
#  'Bacteria (1504).jpeg',
#  'Bacteria (1505).jpeg',
#  'Bacteria (1506).jpeg',
#  'Bacteria (1507).jpeg',
#  'Bacteria (1508).jpeg',
#  'Bacteria (1509).jpeg',
#  'Bacteria (151).jpeg',
#  'Bacteria (1510).jpeg',
#  'Bacteria (1511).jpeg',
#  'Bacteria (1512).jpeg',
#  'Bacteria (1513).jpeg',
#  'Bacteria (1514).jpeg',
#  'Bacteria (1515).jpeg',
#  'Bacteria (1516).jpeg',
#  'Bacteria (1517).jpeg',
#  'Bacteria (1518).jpeg',
#  'Bacteria (1519).jpeg',
#  'Bacteria (152).jpeg',
#  'Bacteria (1520).jpeg',
#  'Bacteria (1521).jpeg',
#  'Bacteria (1522).jpeg',
#  'Bacteria (1523).jpeg',
#  'Bacteria (1524).jpeg',
#  'Bacteria (1525).jpeg',
#  'Bacteria (1526).jpeg',
#  'Bacteria (1527).jpeg',
#  'Bacteria (1528).jpeg',
#  'Bacteria (1529).jpeg',
#  'Bacteria (153).jpeg',
#  'Bacteria (1530).jpeg',
#  'Bacteria (1531).jpeg',
#  'Bacteria (1532).jpeg',
#  'Bacteria (1533).jpeg',
#  'Bacteria (1534).jpeg',
#  'Bacteria (1535).jpeg',
#  'Bacteria (1536).jpeg',
#  'Bacteria (1537).jpeg',
#  'Bacteria (1538).jpeg',
#  'Bacteria (1539).jpeg',
#  'Bacteria (154).jpeg',
#  'Bacteria (1540).jpeg',
#  'Bacteria (1541).jpeg',
#  'Bacteria (1542).jpeg',
#  'Bacteria (1543).jpeg',
#  'Bacteria (1544).jpeg',
#  'Bacteria (1545).jpeg',
#  'Bacteria (1546).jpeg',
#  'Bacteria (1547).jpeg',
#  'Bacteria (1548).jpeg',
#  'Bacteria (1549).jpeg',
#  'Bacteria (155).jpeg',
#  'Bacteria (1550).jpeg',
#  'Bacteria (1551).jpeg',
#  'Bacteria (1552).jpeg',
#  'Bacteria (1553).jpeg',
#  'Bacteria (1554).jpeg',
#  'Bacteria (1555).jpeg',
#  'Bacteria (1556).jpeg',
#  'Bacteria (1557).jpeg',
#  'Bacteria (1558).jpeg',
#  'Bacteria (1559).jpeg',
#  'Bacteria (156).jpeg',
#  'Bacteria (1560).jpeg',
#  'Bacteria (1561).jpeg',
#  'Bacteria (1562).jpeg',
#  'Bacteria (1563).jpeg',
#  'Bacteria (1564).jpeg',
#  'Bacteria (1565).jpeg',
#  'Bacteria (1566).jpeg',
#  'Bacteria (1567).jpeg',
#  'Bacteria (1568).jpeg',
#  'Bacteria (1569).jpeg',
#  'Bacteria (157).jpeg',
#  'Bacteria (1570).jpeg',
#  'Bacteria (1571).jpeg',
#  'Bacteria (1572).jpeg',
#  'Bacteria (1573).jpeg',
#  'Bacteria (1574).jpeg',
#  'Bacteria (1575).jpeg',
#  'Bacteria (1576).jpeg',
#  'Bacteria (1577).jpeg',
#  'Bacteria (1578).jpeg',
#  'Bacteria (1579).jpeg',
#  'Bacteria (158).jpeg',
#  'Bacteria (1580).jpeg',
#  'Bacteria (1581).jpeg',
#  'Bacteria (1582).jpeg',
#  'Bacteria (1583).jpeg',
#  'Bacteria (1584).jpeg',
#  'Bacteria (1585).jpeg',
#  'Bacteria (1586).jpeg',
#  'Bacteria (1587).jpeg',
#  'Bacteria (1588).jpeg',
#  'Bacteria (1589).jpeg',
#  'Bacteria (159).jpeg',
#  'Bacteria (1590).jpeg',
#  'Bacteria (1591).jpeg',
#  'Bacteria (1592).jpeg',
#  'Bacteria (1593).jpeg',
#  'Bacteria (1594).jpeg',
#  'Bacteria (1595).jpeg',
#  'Bacteria (1596).jpeg',
#  'Bacteria (1597).jpeg',
#  'Bacteria (1598).jpeg',
#  'Bacteria (1599).jpeg',
#  'Bacteria (16).jpeg',
#  'Bacteria (160).jpeg',
#  'Bacteria (1600).jpeg',
#  'Bacteria (1601).jpeg',
#  'Bacteria (1602).jpeg',
#  'Bacteria (1603).jpeg',
#  'Bacteria (1604).jpeg',
#  'Bacteria (1605).jpeg',
#  'Bacteria (1606).jpeg',
#  'Bacteria (1607).jpeg',
#  'Bacteria (1608).jpeg',
#  'Bacteria (1609).jpeg',
#  'Bacteria (161).jpeg',
#  'Bacteria (1610).jpeg',
#  'Bacteria (1611).jpeg',
#  'Bacteria (1612).jpeg',
#  'Bacteria (1613).jpeg',
#  'Bacteria (1614).jpeg',
#  'Bacteria (1615).jpeg',
#  'Bacteria (1616).jpeg',
#  'Bacteria (1617).jpeg',
#  'Bacteria (1618).jpeg',
#  'Bacteria (1619).jpeg',
#  'Bacteria (162).jpeg',
#  'Bacteria (1620).jpeg',
#  'Bacteria (1621).jpeg',
#  'Bacteria (1622).jpeg',
#  'Bacteria (1623).jpeg',
#  'Bacteria (1624).jpeg',
#  'Bacteria (1625).jpeg',
#  'Bacteria (1626).jpeg',
#  'Bacteria (1627).jpeg',
#  'Bacteria (1628).jpeg',
#  'Bacteria (1629).jpeg',
#  'Bacteria (163).jpeg',
#  'Bacteria (1630).jpeg',
#  'Bacteria (1631).jpeg',
#  'Bacteria (1632).jpeg',
#  'Bacteria (1633).jpeg',
#  'Bacteria (1634).jpeg',
#  'Bacteria (1635).jpeg',
#  'Bacteria (1636).jpeg',
#  'Bacteria (1637).jpeg',
#  'Bacteria (1638).jpeg',
#  'Bacteria (1639).jpeg',
#  'Bacteria (164).jpeg',
#  'Bacteria (1640).jpeg',
#  'Bacteria (1641).jpeg',
#  'Bacteria (1642).jpeg',
#  'Bacteria (1643).jpeg',
#  'Bacteria (1644).jpeg',
#  'Bacteria (1645).jpeg',
#  'Bacteria (1646).jpeg',
#  'Bacteria (1647).jpeg',
#  'Bacteria (1648).jpeg',
#  'Bacteria (1649).jpeg',
#  'Bacteria (165).jpeg',
#  'Bacteria (1650).jpeg',
#  'Bacteria (1651).jpeg',
#  'Bacteria (1652).jpeg',
#  'Bacteria (1653).jpeg',
#  'Bacteria (1654).jpeg',
#  'Bacteria (1655).jpeg',
#  'Bacteria (1656).jpeg',
#  'Bacteria (1657).jpeg',
#  'Bacteria (1658).jpeg',
#  'Bacteria (1659).jpeg',
#  'Bacteria (166).jpeg',
#  'Bacteria (1660).jpeg',
#  'Bacteria (1661).jpeg',
#  'Bacteria (1662).jpeg',
#  'Bacteria (1663).jpeg',
#  'Bacteria (1664).jpeg',
#  'Bacteria (1665).jpeg',
#  'Bacteria (1666).jpeg',
#  'Bacteria (1667).jpeg',
#  'Bacteria (1668).jpeg',
#  'Bacteria (1669).jpeg',
#  'Bacteria (167).jpeg',
#  'Bacteria (1670).jpeg',
#  'Bacteria (1671).jpeg',
#  'Bacteria (1672).jpeg',
#  'Bacteria (1673).jpeg',
#  'Bacteria (1674).jpeg',
#  'Bacteria (1675).jpeg',
#  'Bacteria (1676).jpeg',
#  'Bacteria (1677).jpeg',
#  'Bacteria (1678).jpeg',
#  'Bacteria (1679).jpeg',
#  'Bacteria (168).jpeg',
#  'Bacteria (1680).jpeg',
#  'Bacteria (1681).jpeg',
#  'Bacteria (1682).jpeg',
#  'Bacteria (1683).jpeg',
#  'Bacteria (1684).jpeg',
#  'Bacteria (1685).jpeg',
#  'Bacteria (1686).jpeg',
#  'Bacteria (1687).jpeg',
#  'Bacteria (1688).jpeg',
#  'Bacteria (1689).jpeg',
#  'Bacteria (169).jpeg',
#  'Bacteria (1690).jpeg',
#  'Bacteria (1691).jpeg',
#  'Bacteria (1692).jpeg',
#  'Bacteria (1693).jpeg',
#  'Bacteria (1694).jpeg',
#  'Bacteria (1695).jpeg',
#  'Bacteria (1696).jpeg',
#  'Bacteria (1697).jpeg',
#  'Bacteria (1698).jpeg',
#  'Bacteria (1699).jpeg',
#  'Bacteria (17).jpeg',
#  'Bacteria (170).jpeg',
#  'Bacteria (1700).jpeg',
#  'Bacteria (1701).jpeg',
#  'Bacteria (1702).jpeg',
#  'Bacteria (1703).jpeg',
#  'Bacteria (1704).jpeg',
#  'Bacteria (1705).jpeg',
#  'Bacteria (1706).jpeg',
#  'Bacteria (1707).jpeg',
#  'Bacteria (1708).jpeg',
#  'Bacteria (1709).jpeg',
#  'Bacteria (171).jpeg',
#  'Bacteria (1710).jpeg',
#  'Bacteria (1711).jpeg',
#  'Bacteria (1712).jpeg',
#  'Bacteria (1713).jpeg',
#  'Bacteria (1714).jpeg',
#  'Bacteria (1715).jpeg',
#  'Bacteria (1716).jpeg',
#  'Bacteria (1717).jpeg',
#  'Bacteria (1718).jpeg',
#  'Bacteria (1719).jpeg',
#  'Bacteria (172).jpeg',
#  'Bacteria (1720).jpeg',
#  'Bacteria (1721).jpeg',
#  'Bacteria (1722).jpeg',
#  'Bacteria (1723).jpeg',
#  'Bacteria (1724).jpeg',
#  'Bacteria (1725).jpeg',
#  'Bacteria (1726).jpeg',
#  'Bacteria (1727).jpeg',
#  'Bacteria (1728).jpeg',
#  'Bacteria (1729).jpeg',
#  'Bacteria (173).jpeg',
#  'Bacteria (1730).jpeg',
#  'Bacteria (1731).jpeg',
#  'Bacteria (1732).jpeg',
#  'Bacteria (1733).jpeg',
#  'Bacteria (1734).jpeg',
#  'Bacteria (1735).jpeg',
#  'Bacteria (1736).jpeg',
#  'Bacteria (1737).jpeg',
#  'Bacteria (1738).jpeg',
#  'Bacteria (1739).jpeg',
#  'Bacteria (174).jpeg',
#  'Bacteria (1740).jpeg',
#  'Bacteria (1741).jpeg',
#  'Bacteria (1742).jpeg',
#  'Bacteria (1743).jpeg',
#  'Bacteria (1744).jpeg',
#  'Bacteria (1745).jpeg',
#  'Bacteria (1746).jpeg',
#  'Bacteria (1747).jpeg',
#  'Bacteria (1748).jpeg',
#  'Bacteria (1749).jpeg',
#  'Bacteria (175).jpeg',
#  'Bacteria (1750).jpeg',
#  'Bacteria (1751).jpeg',
#  'Bacteria (1752).jpeg',
#  'Bacteria (1753).jpeg',
#  'Bacteria (1754).jpeg',
#  'Bacteria (1755).jpeg',
#  'Bacteria (1756).jpeg',
#  'Bacteria (1757).jpeg',
#  'Bacteria (1758).jpeg',
#  'Bacteria (1759).jpeg',
#  'Bacteria (176).jpeg',
#  'Bacteria (1760).jpeg',
#  'Bacteria (1761).jpeg',
#  'Bacteria (1762).jpeg',
#  'Bacteria (1763).jpeg',
#  'Bacteria (1764).jpeg',
#  'Bacteria (1765).jpeg',
#  'Bacteria (1766).jpeg',
#  'Bacteria (1767).jpeg',
#  'Bacteria (1768).jpeg',
#  'Bacteria (1769).jpeg',
#  'Bacteria (177).jpeg',
#  'Bacteria (1770).jpeg',
#  'Bacteria (1771).jpeg',
#  'Bacteria (1772).jpeg',
#  'Bacteria (1773).jpeg',
#  'Bacteria (1774).jpeg',
#  'Bacteria (1775).jpeg',
#  'Bacteria (1776).jpeg',
#  'Bacteria (1777).jpeg',
#  'Bacteria (1778).jpeg',
#  'Bacteria (1779).jpeg',
#  'Bacteria (178).jpeg',
#  'Bacteria (1780).jpeg',
#  'Bacteria (1781).jpeg',
#  'Bacteria (1782).jpeg',
#  'Bacteria (1783).jpeg',
#  'Bacteria (1784).jpeg',
#  'Bacteria (1785).jpeg',
#  'Bacteria (1786).jpeg',
#  'Bacteria (1787).jpeg',
#  'Bacteria (1788).jpeg',
#  'Bacteria (1789).jpeg',
#  'Bacteria (179).jpeg',
#  'Bacteria (1790).jpeg',
#  'Bacteria (1791).jpeg',
#  'Bacteria (1792).jpeg',
#  'Bacteria (1793).jpeg',
#  'Bacteria (1794).jpeg',
#  'Bacteria (1795).jpeg',
#  'Bacteria (1796).jpeg',
#  'Bacteria (1797).jpeg',
#  'Bacteria (1798).jpeg',
#  'Bacteria (1799).jpeg',
#  'Bacteria (18).jpeg',
#  'Bacteria (180).jpeg',
#  'Bacteria (1800).jpeg',
#  'Bacteria (1801).jpeg',
#  'Bacteria (1802).jpeg',
#  'Bacteria (1803).jpeg',
#  'Bacteria (1804).jpeg',
#  'Bacteria (1805).jpeg',
#  'Bacteria (1806).jpeg',
#  'Bacteria (1807).jpeg',
#  'Bacteria (1808).jpeg',
#  'Bacteria (1809).jpeg',
#  'Bacteria (181).jpeg',
#  'Bacteria (1810).jpeg',
#  'Bacteria (1811).jpeg',
#  'Bacteria (1812).jpeg',
#  'Bacteria (1813).jpeg',
#  'Bacteria (1814).jpeg',
#  'Bacteria (1815).jpeg',
#  'Bacteria (1816).jpeg',
#  'Bacteria (1817).jpeg',
#  'Bacteria (1818).jpeg',
#  'Bacteria (1819).jpeg',
#  'Bacteria (182).jpeg',
#  'Bacteria (1820).jpeg',
#  'Bacteria (1821).jpeg',
#  'Bacteria (1822).jpeg',
#  'Bacteria (1823).jpeg',
#  'Bacteria (1824).jpeg',
#  'Bacteria (1825).jpeg',
#  'Bacteria (1826).jpeg',
#  'Bacteria (1827).jpeg',
#  'Bacteria (1828).jpeg',
#  'Bacteria (1829).jpeg',
#  'Bacteria (183).jpeg',
#  'Bacteria (1830).jpeg',
#  'Bacteria (1831).jpeg',
#  'Bacteria (1832).jpeg',
#  'Bacteria (1833).jpeg',
#  'Bacteria (1834).jpeg',
#  'Bacteria (1835).jpeg',
#  'Bacteria (1836).jpeg',
#  'Bacteria (1837).jpeg',
#  'Bacteria (1838).jpeg',
#  'Bacteria (1839).jpeg',
#  'Bacteria (184).jpeg',
#  'Bacteria (1840).jpeg',
#  'Bacteria (1841).jpeg',
#  'Bacteria (1842).jpeg',
#  'Bacteria (1843).jpeg',
#  'Bacteria (1844).jpeg',
#  'Bacteria (1845).jpeg',
#  'Bacteria (1846).jpeg',
#  'Bacteria (1847).jpeg',
#  'Bacteria (1848).jpeg',
#  'Bacteria (1849).jpeg',
#  'Bacteria (185).jpeg',
#  'Bacteria (1850).jpeg',
#  'Bacteria (1851).jpeg',
#  'Bacteria (1852).jpeg',
#  'Bacteria (1853).jpeg',
#  'Bacteria (1854).jpeg',
#  'Bacteria (1855).jpeg',
#  'Bacteria (1856).jpeg',
#  'Bacteria (1857).jpeg',
#  'Bacteria (1858).jpeg',
#  'Bacteria (1859).jpeg',
#  'Bacteria (186).jpeg',
#  'Bacteria (1860).jpeg',
#  'Bacteria (1861).jpeg',
#  'Bacteria (1862).jpeg',
#  'Bacteria (1863).jpeg',
#  'Bacteria (1864).jpeg',
#  'Bacteria (1865).jpeg',
#  'Bacteria (1866).jpeg',
#  'Bacteria (1867).jpeg',
#  'Bacteria (1868).jpeg',
#  'Bacteria (1869).jpeg',
#  'Bacteria (187).jpeg',
#  'Bacteria (1870).jpeg',
#  'Bacteria (1871).jpeg',
#  'Bacteria (1872).jpeg',
#  'Bacteria (1873).jpeg',
#  'Bacteria (1874).jpeg',
#  'Bacteria (1875).jpeg',
#  'Bacteria (1876).jpeg',
#  'Bacteria (1877).jpeg',
#  'Bacteria (1878).jpeg',
#  'Bacteria (1879).jpeg',
#  'Bacteria (188).jpeg',
#  'Bacteria (1880).jpeg',
#  'Bacteria (1881).jpeg',
#  'Bacteria (1882).jpeg',
#  'Bacteria (1883).jpeg',
#  'Bacteria (1884).jpeg',
#  'Bacteria (1885).jpeg',
#  'Bacteria (1886).jpeg',
#  'Bacteria (1887).jpeg',
#  'Bacteria (1888).jpeg',
#  'Bacteria (1889).jpeg',
#  'Bacteria (189).jpeg',
#  'Bacteria (1890).jpeg',
#  'Bacteria (1891).jpeg',
#  'Bacteria (1892).jpeg',
#  'Bacteria (1893).jpeg',
#  'Bacteria (1894).jpeg',
#  'Bacteria (1895).jpeg',
#  'Bacteria (1896).jpeg',
#  'Bacteria (1897).jpeg',
#  'Bacteria (1898).jpeg',
#  'Bacteria (1899).jpeg',
#  ...]

# %%
# 肺部感染的图片
files_normalViral_pneumonia = os.listdir(os.path.join(str(dataloaders['train'].dataset.root), 'normalViral'))
files_normalViral_pneumonia
# Out:
# ['Normal (1).jpeg',
#  'Normal (1).png',
#  'Normal (10).jpeg',
#  'Normal (10).png',
#  'Normal (100).jpeg',
#  'Normal (100).png',
#  'Normal (1000).jpeg',
#  'Normal (1000).png',
#  'Normal (1001).jpeg',
#  'Normal (1001).png',
#  'Normal (1002).jpeg',
#  'Normal (1002).png',
#  'Normal (1003).jpeg',
#  'Normal (1003).png',
#  'Normal (1004).jpeg',
#  'Normal (1004).png',
#  'Normal (1005).jpeg',
#  'Normal (1005).png',
#  'Normal (1006).jpeg',
#  'Normal (1006).png',
#  'Normal (1007).jpeg',
#  'Normal (1007).png',
#  'Normal (1008).jpeg',
#  'Normal (1008).png',
#  'Normal (1009).jpeg',
#  'Normal (1009).png',
#  'Normal (101).jpeg',
#  'Normal (101).png',
#  'Normal (1010).jpeg',
#  'Normal (1010).png',
#  'Normal (1011).jpeg',
#  'Normal (1011).png',
#  'Normal (1012).jpeg',
#  'Normal (1012).png',
#  'Normal (1013).jpeg',
#  'Normal (1013).png',
#  'Normal (1014).jpeg',
#  'Normal (1014).png',
#  'Normal (1015).jpeg',
#  'Normal (1015).png',
#  'Normal (1016).jpeg',
#  'Normal (1016).png',
#  'Normal (1017).jpeg',
#  'Normal (1017).png',
#  'Normal (1018).jpeg',
#  'Normal (1018).png',
#  'Normal (1019).jpeg',
#  'Normal (1019).png',
#  'Normal (102).jpeg',
#  'Normal (102).png',
#  'Normal (1020).jpeg',
#  'Normal (1020).png',
#  'Normal (1021).jpeg',
#  'Normal (1021).png',
#  'Normal (1022).jpeg',
#  'Normal (1022).png',
#  'Normal (1023).jpeg',
#  'Normal (1023).png',
#  'Normal (1024).jpeg',
#  'Normal (1024).png',
#  'Normal (1025).jpeg',
#  'Normal (1025).png',
#  'Normal (1026).jpeg',
#  'Normal (1026).png',
#  'Normal (1027).jpeg',
#  'Normal (1027).png',
#  'Normal (1028).jpeg',
#  'Normal (1028).png',
#  'Normal (1029).jpeg',
#  'Normal (1029).png',
#  'Normal (103).jpeg',
#  'Normal (103).png',
#  'Normal (1030).jpeg',
#  'Normal (1030).png',
#  'Normal (1031).jpeg',
#  'Normal (1031).png',
#  'Normal (1032).jpeg',
#  'Normal (1032).png',
#  'Normal (1033).jpeg',
#  'Normal (1033).png',
#  'Normal (1034).jpeg',
#  'Normal (1034).png',
#  'Normal (1035).jpeg',
#  'Normal (1035).png',
#  'Normal (1036).jpeg',
#  'Normal (1036).png',
#  'Normal (1037).jpeg',
#  'Normal (1037).png',
#  'Normal (1038).jpeg',
#  'Normal (1038).png',
#  'Normal (1039).jpeg',
#  'Normal (1039).png',
#  'Normal (104).jpeg',
#  'Normal (104).png',
#  'Normal (1040).jpeg',
#  'Normal (1040).png',
#  'Normal (1041).jpeg',
#  'Normal (1041).png',
#  'Normal (1042).jpeg',
#  'Normal (1042).png',
#  'Normal (1043).jpeg',
#  'Normal (1043).png',
#  'Normal (1044).jpeg',
#  'Normal (1044).png',
#  'Normal (1045).jpeg',
#  'Normal (1045).png',
#  'Normal (1046).jpeg',
#  'Normal (1046).png',
#  'Normal (1047).jpeg',
#  'Normal (1047).png',
#  'Normal (1048).jpeg',
#  'Normal (1048).png',
#  'Normal (1049).jpeg',
#  'Normal (1049).png',
#  'Normal (105).jpeg',
#  'Normal (105).png',
#  'Normal (1050).jpeg',
#  'Normal (1050).png',
#  'Normal (1051).jpeg',
#  'Normal (1051).png',
#  'Normal (1052).jpeg',
#  'Normal (1052).png',
#  'Normal (1053).jpeg',
#  'Normal (1053).png',
#  'Normal (1054).jpeg',
#  'Normal (1054).png',
#  'Normal (1055).jpeg',
#  'Normal (1055).png',
#  'Normal (1056).jpeg',
#  'Normal (1056).png',
#  'Normal (1057).jpeg',
#  'Normal (1057).png',
#  'Normal (1058).jpeg',
#  'Normal (1058).png',
#  'Normal (1059).jpeg',
#  'Normal (1059).png',
#  'Normal (106).jpeg',
#  'Normal (106).png',
#  'Normal (1060).jpeg',
#  'Normal (1060).png',
#  'Normal (1061).jpeg',
#  'Normal (1061).png',
#  'Normal (1062).jpeg',
#  'Normal (1062).png',
#  'Normal (1063).jpeg',
#  'Normal (1063).png',
#  'Normal (1064).jpeg',
#  'Normal (1064).png',
#  'Normal (1065).jpeg',
#  'Normal (1065).png',
#  'Normal (1066).jpeg',
#  'Normal (1066).png',
#  'Normal (1067).jpeg',
#  'Normal (1067).png',
#  'Normal (1068).jpeg',
#  'Normal (1068).png',
#  'Normal (1069).jpeg',
#  'Normal (1069).png',
#  'Normal (107).jpeg',
#  'Normal (107).png',
#  'Normal (1070).jpeg',
#  'Normal (1070).png',
#  'Normal (1071).jpeg',
#  'Normal (1071).png',
#  'Normal (1072).jpeg',
#  'Normal (1072).png',
#  'Normal (1073).jpeg',
#  'Normal (1073).png',
#  'Normal (1074).jpeg',
#  'Normal (1074).png',
#  'Normal (1075).jpeg',
#  'Normal (1075).png',
#  'Normal (1076).jpeg',
#  'Normal (1076).png',
#  'Normal (1077).jpeg',
#  'Normal (1077).png',
#  'Normal (1078).jpeg',
#  'Normal (1078).png',
#  'Normal (1079).jpeg',
#  'Normal (1079).png',
#  'Normal (108).jpeg',
#  'Normal (108).png',
#  'Normal (1080).jpeg',
#  'Normal (1080).png',
#  'Normal (1081).jpeg',
#  'Normal (1081).png',
#  'Normal (1082).jpeg',
#  'Normal (1082).png',
#  'Normal (1083).jpeg',
#  'Normal (1083).png',
#  'Normal (1084).jpeg',
#  'Normal (1084).png',
#  'Normal (1085).jpeg',
#  'Normal (1085).png',
#  'Normal (1086).jpeg',
#  'Normal (1086).png',
#  'Normal (1087).jpeg',
#  'Normal (1087).png',
#  'Normal (1088).jpeg',
#  'Normal (1088).png',
#  'Normal (1089).jpeg',
#  'Normal (1089).png',
#  'Normal (109).jpeg',
#  'Normal (109).png',
#  'Normal (1090).jpeg',
#  'Normal (1090).png',
#  'Normal (1091).jpeg',
#  'Normal (1091).png',
#  'Normal (1092).jpeg',
#  'Normal (1092).png',
#  'Normal (1093).jpeg',
#  'Normal (1093).png',
#  'Normal (1094).jpeg',
#  'Normal (1094).png',
#  'Normal (1095).jpeg',
#  'Normal (1095).png',
#  'Normal (1096).jpeg',
#  'Normal (1096).png',
#  'Normal (1097).jpeg',
#  'Normal (1097).png',
#  'Normal (1098).jpeg',
#  'Normal (1098).png',
#  'Normal (1099).jpeg',
#  'Normal (1099).png',
#  'Normal (11).jpeg',
#  'Normal (11).png',
#  'Normal (110).jpeg',
#  'Normal (110).png',
#  'Normal (1100).jpeg',
#  'Normal (1100).png',
#  'Normal (1101).jpeg',
#  'Normal (1101).png',
#  'Normal (1102).jpeg',
#  'Normal (1102).png',
#  'Normal (1103).jpeg',
#  'Normal (1103).png',
#  'Normal (1104).jpeg',
#  'Normal (1104).png',
#  'Normal (1105).jpeg',
#  'Normal (1105).png',
#  'Normal (1106).jpeg',
#  'Normal (1106).png',
#  'Normal (1107).jpeg',
#  'Normal (1107).png',
#  'Normal (1108).jpeg',
#  'Normal (1108).png',
#  'Normal (1109).jpeg',
#  'Normal (1109).png',
#  'Normal (111).jpeg',
#  'Normal (111).png',
#  'Normal (1110).jpeg',
#  'Normal (1110).png',
#  'Normal (1111).jpeg',
#  'Normal (1111).png',
#  'Normal (1112).jpeg',
#  'Normal (1112).png',
#  'Normal (1113).jpeg',
#  'Normal (1113).png',
#  'Normal (1114).jpeg',
#  'Normal (1114).png',
#  'Normal (1115).jpeg',
#  'Normal (1115).png',
#  'Normal (1116).jpeg',
#  'Normal (1116).png',
#  'Normal (1117).jpeg',
#  'Normal (1117).png',
#  'Normal (1118).jpeg',
#  'Normal (1118).png',
#  'Normal (1119).jpeg',
#  'Normal (1119).png',
#  'Normal (112).jpeg',
#  'Normal (112).png',
#  'Normal (1120).jpeg',
#  'Normal (1120).png',
#  'Normal (1121).jpeg',
#  'Normal (1121).png',
#  'Normal (1122).jpeg',
#  'Normal (1122).png',
#  'Normal (1123).jpeg',
#  'Normal (1123).png',
#  'Normal (1124).jpeg',
#  'Normal (1124).png',
#  'Normal (1125).jpeg',
#  'Normal (1125).png',
#  'Normal (1126).jpeg',
#  'Normal (1126).png',
#  'Normal (1127).jpeg',
#  'Normal (1127).png',
#  'Normal (1128).jpeg',
#  'Normal (1128).png',
#  'Normal (1129).jpeg',
#  'Normal (1129).png',
#  'Normal (113).jpeg',
#  'Normal (113).png',
#  'Normal (1130).jpeg',
#  'Normal (1130).png',
#  'Normal (1131).jpeg',
#  'Normal (1131).png',
#  'Normal (1132).jpeg',
#  'Normal (1132).png',
#  'Normal (1133).jpeg',
#  'Normal (1133).png',
#  'Normal (1134).jpeg',
#  'Normal (1134).png',
#  'Normal (1135).jpeg',
#  'Normal (1135).png',
#  'Normal (1136).jpeg',
#  'Normal (1136).png',
#  'Normal (1137).jpeg',
#  'Normal (1137).png',
#  'Normal (1138).jpeg',
#  'Normal (1138).png',
#  'Normal (1139).jpeg',
#  'Normal (1139).png',
#  'Normal (114).jpeg',
#  'Normal (114).png',
#  'Normal (1140).jpeg',
#  'Normal (1140).png',
#  'Normal (1141).jpeg',
#  'Normal (1141).png',
#  'Normal (1142).jpeg',
#  'Normal (1142).png',
#  'Normal (1143).jpeg',
#  'Normal (1143).png',
#  'Normal (1144).jpeg',
#  'Normal (1144).png',
#  'Normal (1145).jpeg',
#  'Normal (1145).png',
#  'Normal (1146).jpeg',
#  'Normal (1146).png',
#  'Normal (1147).jpeg',
#  'Normal (1147).png',
#  'Normal (1148).jpeg',
#  'Normal (1148).png',
#  'Normal (1149).jpeg',
#  'Normal (1149).png',
#  'Normal (115).jpeg',
#  'Normal (115).png',
#  'Normal (1150).jpeg',
#  'Normal (1150).png',
#  'Normal (1151).jpeg',
#  'Normal (1151).png',
#  'Normal (1152).jpeg',
#  'Normal (1152).png',
#  'Normal (1153).jpeg',
#  'Normal (1153).png',
#  'Normal (1154).jpeg',
#  'Normal (1154).png',
#  'Normal (1155).jpeg',
#  'Normal (1155).png',
#  'Normal (1156).jpeg',
#  'Normal (1156).png',
#  'Normal (1157).jpeg',
#  'Normal (1157).png',
#  'Normal (1158).jpeg',
#  'Normal (1158).png',
#  'Normal (1159).jpeg',
#  'Normal (1159).png',
#  'Normal (116).jpeg',
#  'Normal (116).png',
#  'Normal (1160).jpeg',
#  'Normal (1160).png',
#  'Normal (1161).jpeg',
#  'Normal (1161).png',
#  'Normal (1162).jpeg',
#  'Normal (1162).png',
#  'Normal (1163).jpeg',
#  'Normal (1163).png',
#  'Normal (1164).jpeg',
#  'Normal (1164).png',
#  'Normal (1165).jpeg',
#  'Normal (1165).png',
#  'Normal (1166).jpeg',
#  'Normal (1166).png',
#  'Normal (1167).jpeg',
#  'Normal (1167).png',
#  'Normal (1168).jpeg',
#  'Normal (1168).png',
#  'Normal (1169).jpeg',
#  'Normal (1169).png',
#  'Normal (117).jpeg',
#  'Normal (117).png',
#  'Normal (1170).jpeg',
#  'Normal (1170).png',
#  'Normal (1171).jpeg',
#  'Normal (1171).png',
#  'Normal (1172).jpeg',
#  'Normal (1172).png',
#  'Normal (1173).jpeg',
#  'Normal (1173).png',
#  'Normal (1174).jpeg',
#  'Normal (1174).png',
#  'Normal (1175).jpeg',
#  'Normal (1175).png',
#  'Normal (1176).jpeg',
#  'Normal (1176).png',
#  'Normal (1177).jpeg',
#  'Normal (1177).png',
#  'Normal (1178).jpeg',
#  'Normal (1178).png',
#  'Normal (1179).jpeg',
#  'Normal (1179).png',
#  'Normal (118).jpeg',
#  'Normal (118).png',
#  'Normal (1180).jpeg',
#  'Normal (1180).png',
#  'Normal (1181).jpeg',
#  'Normal (1181).png',
#  'Normal (1182).jpeg',
#  'Normal (1182).png',
#  'Normal (1183).jpeg',
#  'Normal (1183).png',
#  'Normal (1184).jpeg',
#  'Normal (1184).png',
#  'Normal (1185).jpeg',
#  'Normal (1185).png',
#  'Normal (1186).jpeg',
#  'Normal (1186).png',
#  'Normal (1187).jpeg',
#  'Normal (1187).png',
#  'Normal (1188).jpeg',
#  'Normal (1188).png',
#  'Normal (1189).jpeg',
#  'Normal (1189).png',
#  'Normal (119).jpeg',
#  'Normal (119).png',
#  'Normal (1190).jpeg',
#  'Normal (1190).png',
#  'Normal (1191).jpeg',
#  'Normal (1191).png',
#  'Normal (1192).jpeg',
#  'Normal (1192).png',
#  'Normal (1193).jpeg',
#  'Normal (1193).png',
#  'Normal (1194).jpeg',
#  'Normal (1194).png',
#  'Normal (1195).jpeg',
#  'Normal (1195).png',
#  'Normal (1196).jpeg',
#  'Normal (1196).png',
#  'Normal (1197).jpeg',
#  'Normal (1197).png',
#  'Normal (1198).jpeg',
#  'Normal (1198).png',
#  'Normal (1199).jpeg',
#  'Normal (1199).png',
#  'Normal (12).jpeg',
#  'Normal (12).png',
#  'Normal (120).jpeg',
#  'Normal (120).png',
#  'Normal (1200).jpeg',
#  'Normal (1200).png',
#  'Normal (1201).jpeg',
#  'Normal (1201).png',
#  'Normal (1202).jpeg',
#  'Normal (1202).png',
#  'Normal (1203).jpeg',
#  'Normal (1203).png',
#  'Normal (1204).jpeg',
#  'Normal (1204).png',
#  'Normal (1205).jpeg',
#  'Normal (1205).png',
#  'Normal (1206).jpeg',
#  'Normal (1206).png',
#  'Normal (1207).jpeg',
#  'Normal (1207).png',
#  'Normal (1208).jpeg',
#  'Normal (1208).png',
#  'Normal (1209).jpeg',
#  'Normal (1209).png',
#  'Normal (121).jpeg',
#  'Normal (121).png',
#  'Normal (1210).jpeg',
#  'Normal (1210).png',
#  'Normal (1211).jpeg',
#  'Normal (1211).png',
#  'Normal (1212).jpeg',
#  'Normal (1212).png',
#  'Normal (1213).jpeg',
#  'Normal (1213).png',
#  'Normal (1214).jpeg',
#  'Normal (1214).png',
#  'Normal (1215).jpeg',
#  'Normal (1215).png',
#  'Normal (1216).jpeg',
#  'Normal (1216).png',
#  'Normal (1217).jpeg',
#  'Normal (1217).png',
#  'Normal (1218).jpeg',
#  'Normal (1218).png',
#  'Normal (1219).jpeg',
#  'Normal (1219).png',
#  'Normal (122).jpeg',
#  'Normal (122).png',
#  'Normal (1220).jpeg',
#  'Normal (1220).png',
#  'Normal (1221).jpeg',
#  'Normal (1221).png',
#  'Normal (1222).jpeg',
#  'Normal (1222).png',
#  'Normal (1223).jpeg',
#  'Normal (1223).png',
#  'Normal (1224).jpeg',
#  'Normal (1224).png',
#  'Normal (1225).jpeg',
#  'Normal (1225).png',
#  'Normal (1226).jpeg',
#  'Normal (1226).png',
#  'Normal (1227).jpeg',
#  'Normal (1227).png',
#  'Normal (1228).jpeg',
#  'Normal (1228).png',
#  'Normal (1229).jpeg',
#  'Normal (1229).png',
#  'Normal (123).jpeg',
#  'Normal (123).png',
#  'Normal (1230).jpeg',
#  'Normal (1230).png',
#  'Normal (1231).jpeg',
#  'Normal (1231).png',
#  'Normal (1232).jpeg',
#  'Normal (1232).png',
#  'Normal (1233).jpeg',
#  'Normal (1233).png',
#  'Normal (1234).jpeg',
#  'Normal (1234).png',
#  'Normal (1235).jpeg',
#  'Normal (1235).png',
#  'Normal (1236).jpeg',
#  'Normal (1236).png',
#  'Normal (1237).jpeg',
#  'Normal (1237).png',
#  'Normal (1238).jpeg',
#  'Normal (1238).png',
#  'Normal (1239).jpeg',
#  'Normal (1239).png',
#  'Normal (124).jpeg',
#  'Normal (124).png',
#  'Normal (1240).jpeg',
#  'Normal (1240).png',
#  'Normal (1241).jpeg',
#  'Normal (1241).png',
#  'Normal (1242).jpeg',
#  'Normal (1242).png',
#  'Normal (1243).jpeg',
#  'Normal (1243).png',
#  'Normal (1244).jpeg',
#  'Normal (1244).png',
#  'Normal (1245).jpeg',
#  'Normal (1245).png',
#  'Normal (1246).jpeg',
#  'Normal (1246).png',
#  'Normal (1247).jpeg',
#  'Normal (1247).png',
#  'Normal (1248).jpeg',
#  'Normal (1248).png',
#  'Normal (1249).jpeg',
#  'Normal (1249).png',
#  'Normal (125).jpeg',
#  'Normal (125).png',
#  'Normal (1250).jpeg',
#  'Normal (1250).png',
#  'Normal (1251).jpeg',
#  'Normal (1251).png',
#  'Normal (1252).jpeg',
#  'Normal (1252).png',
#  'Normal (1253).jpeg',
#  'Normal (1253).png',
#  'Normal (1254).jpeg',
#  'Normal (1254).png',
#  'Normal (1255).jpeg',
#  'Normal (1255).png',
#  'Normal (1256).jpeg',
#  'Normal (1256).png',
#  'Normal (1257).jpeg',
#  'Normal (1257).png',
#  'Normal (1258).jpeg',
#  'Normal (1258).png',
#  'Normal (1259).jpeg',
#  'Normal (1259).png',
#  'Normal (126).jpeg',
#  'Normal (126).png',
#  'Normal (1260).jpeg',
#  'Normal (1260).png',
#  'Normal (1261).jpeg',
#  'Normal (1261).png',
#  'Normal (1262).jpeg',
#  'Normal (1262).png',
#  'Normal (1263).jpeg',
#  'Normal (1263).png',
#  'Normal (1264).jpeg',
#  'Normal (1264).png',
#  'Normal (1265).jpeg',
#  'Normal (1265).png',
#  'Normal (1266).jpeg',
#  'Normal (1266).png',
#  'Normal (1267).jpeg',
#  'Normal (1267).png',
#  'Normal (1268).jpeg',
#  'Normal (1268).png',
#  'Normal (1269).jpeg',
#  'Normal (1269).png',
#  'Normal (127).jpeg',
#  'Normal (127).png',
#  'Normal (1270).jpeg',
#  'Normal (1270).png',
#  'Normal (1271).jpeg',
#  'Normal (1271).png',
#  'Normal (1272).jpeg',
#  'Normal (1272).png',
#  'Normal (1273).jpeg',
#  'Normal (1273).png',
#  'Normal (1274).jpeg',
#  'Normal (1274).png',
#  'Normal (1275).jpeg',
#  'Normal (1275).png',
#  'Normal (1276).jpeg',
#  'Normal (1276).png',
#  'Normal (1277).jpeg',
#  'Normal (1277).png',
#  'Normal (1278).jpeg',
#  'Normal (1278).png',
#  'Normal (1279).jpeg',
#  'Normal (1279).png',
#  'Normal (128).jpeg',
#  'Normal (128).png',
#  'Normal (1280).jpeg',
#  'Normal (1280).png',
#  'Normal (1281).jpeg',
#  'Normal (1281).png',
#  'Normal (1282).jpeg',
#  'Normal (1282).png',
#  'Normal (1283).jpeg',
#  'Normal (1283).png',
#  'Normal (1284).jpeg',
#  'Normal (1284).png',
#  'Normal (1285).jpeg',
#  'Normal (1285).png',
#  'Normal (1286).jpeg',
#  'Normal (1286).png',
#  'Normal (1287).jpeg',
#  'Normal (1287).png',
#  'Normal (1288).jpeg',
#  'Normal (1288).png',
#  'Normal (1289).jpeg',
#  'Normal (1289).png',
#  'Normal (129).jpeg',
#  'Normal (129).png',
#  'Normal (1290).jpeg',
#  'Normal (1290).png',
#  'Normal (1291).jpeg',
#  'Normal (1291).png',
#  'Normal (1292).jpeg',
#  'Normal (1292).png',
#  'Normal (1293).jpeg',
#  'Normal (1293).png',
#  'Normal (1294).jpeg',
#  'Normal (1294).png',
#  'Normal (1295).jpeg',
#  'Normal (1295).png',
#  'Normal (1296).jpeg',
#  'Normal (1296).png',
#  'Normal (1297).jpeg',
#  'Normal (1297).png',
#  'Normal (1298).jpeg',
#  'Normal (1298).png',
#  'Normal (1299).jpeg',
#  'Normal (1299).png',
#  'Normal (13).jpeg',
#  'Normal (13).png',
#  'Normal (130).jpeg',
#  'Normal (130).png',
#  'Normal (1300).jpeg',
#  'Normal (1300).png',
#  'Normal (1301).jpeg',
#  'Normal (1301).png',
#  'Normal (1302).jpeg',
#  'Normal (1302).png',
#  'Normal (1303).jpeg',
#  'Normal (1303).png',
#  'Normal (1304).jpeg',
#  'Normal (1304).png',
#  'Normal (1305).jpeg',
#  'Normal (1305).png',
#  'Normal (1306).jpeg',
#  'Normal (1306).png',
#  'Normal (1307).jpeg',
#  'Normal (1307).png',
#  'Normal (1308).jpeg',
#  'Normal (1308).png',
#  'Normal (1309).jpeg',
#  'Normal (1309).png',
#  'Normal (131).jpeg',
#  'Normal (131).png',
#  'Normal (1310).jpeg',
#  'Normal (1310).png',
#  'Normal (1311).jpeg',
#  'Normal (1311).png',
#  'Normal (1312).jpeg',
#  'Normal (1312).png',
#  'Normal (1313).jpeg',
#  'Normal (1313).png',
#  'Normal (1314).jpeg',
#  'Normal (1314).png',
#  'Normal (1315).jpeg',
#  'Normal (1315).png',
#  'Normal (1316).jpeg',
#  'Normal (1316).png',
#  'Normal (1317).jpeg',
#  'Normal (1317).png',
#  'Normal (1318).jpeg',
#  'Normal (1318).png',
#  'Normal (1319).jpeg',
#  'Normal (1319).png',
#  'Normal (132).jpeg',
#  'Normal (132).png',
#  'Normal (1320).jpeg',
#  'Normal (1320).png',
#  'Normal (1321).jpeg',
#  'Normal (1321).png',
#  'Normal (1322).jpeg',
#  'Normal (1322).png',
#  'Normal (1323).jpeg',
#  'Normal (1323).png',
#  'Normal (1324).jpeg',
#  'Normal (1324).png',
#  'Normal (1325).jpeg',
#  'Normal (1325).png',
#  'Normal (1326).jpeg',
#  'Normal (1326).png',
#  'Normal (1327).jpeg',
#  'Normal (1327).png',
#  'Normal (1328).jpeg',
#  'Normal (1328).png',
#  'Normal (1329).jpeg',
#  'Normal (1329).png',
#  'Normal (133).jpeg',
#  'Normal (133).png',
#  'Normal (1330).jpeg',
#  'Normal (1330).png',
#  'Normal (1331).jpeg',
#  'Normal (1331).png',
#  'Normal (1332).jpeg',
#  'Normal (1332).png',
#  'Normal (1333).jpeg',
#  'Normal (1333).png',
#  'Normal (1334).jpeg',
#  'Normal (1334).png',
#  'Normal (1335).jpeg',
#  'Normal (1335).png',
#  'Normal (1336).jpeg',
#  'Normal (1336).png',
#  'Normal (1337).jpeg',
#  'Normal (1337).png',
#  'Normal (1338).jpeg',
#  'Normal (1338).png',
#  'Normal (1339).jpeg',
#  'Normal (1339).png',
#  'Normal (134).jpeg',
#  'Normal (134).png',
#  'Normal (1340).jpeg',
#  'Normal (1340).png',
#  'Normal (1341).jpeg',
#  'Normal (1341).png',
#  'Normal (1342).png',
#  'Normal (1343).png',
#  'Normal (1344).png',
#  'Normal (1345).png',
#  'Normal (1346).png',
#  'Normal (1347).png',
#  'Normal (1348).png',
#  'Normal (1349).png',
#  'Normal (135).jpeg',
#  'Normal (135).png',
#  'Normal (1350).png',
#  'Normal (1351).png',
#  'Normal (1352).png',
#  'Normal (1353).png',
#  'Normal (1354).png',
#  'Normal (1355).png',
#  'Normal (1356).png',
#  'Normal (1357).png',
#  'Normal (1358).png',
#  'Normal (1359).png',
#  'Normal (136).jpeg',
#  'Normal (136).png',
#  'Normal (1360).png',
#  'Normal (1361).png',
#  'Normal (1362).png',
#  'Normal (1363).png',
#  'Normal (1364).png',
#  'Normal (1365).png',
#  'Normal (1366).png',
#  'Normal (1367).png',
#  'Normal (1368).png',
#  'Normal (1369).png',
#  'Normal (137).jpeg',
#  'Normal (137).png',
#  'Normal (1370).png',
#  'Normal (1371).png',
#  'Normal (1372).png',
#  'Normal (1373).png',
#  'Normal (1374).png',
#  'Normal (1375).png',
#  'Normal (1376).png',
#  'Normal (1377).png',
#  'Normal (1378).png',
#  'Normal (1379).png',
#  'Normal (138).jpeg',
#  'Normal (138).png',
#  'Normal (1380).png',
#  'Normal (1381).png',
#  'Normal (1382).png',
#  'Normal (1383).png',
#  'Normal (1384).png',
#  'Normal (1385).png',
#  'Normal (1386).png',
#  'Normal (1387).png',
#  'Normal (1388).png',
#  'Normal (1389).png',
#  'Normal (139).jpeg',
#  'Normal (139).png',
#  'Normal (1390).png',
#  'Normal (1391).png',
#  'Normal (1392).png',
#  'Normal (1393).png',
#  'Normal (1394).png',
#  'Normal (1395).png',
#  'Normal (1396).png',
#  'Normal (1397).png',
#  'Normal (1398).png',
#  'Normal (1399).png',
#  'Normal (14).jpeg',
#  'Normal (14).png',
#  'Normal (140).jpeg',
#  'Normal (140).png',
#  'Normal (1400).png',
#  'Normal (1401).png',
#  'Normal (1402).png',
#  'Normal (1403).png',
#  'Normal (1404).png',
#  'Normal (1405).png',
#  'Normal (1406).png',
#  'Normal (1407).png',
#  'Normal (1408).png',
#  'Normal (1409).png',
#  'Normal (141).jpeg',
#  'Normal (141).png',
#  'Normal (1410).png',
#  'Normal (1411).png',
#  'Normal (1412).png',
#  'Normal (1413).png',
#  'Normal (1414).png',
#  'Normal (1415).png',
#  'Normal (1416).png',
#  'Normal (1417).png',
#  'Normal (1418).png',
#  'Normal (1419).png',
#  'Normal (142).jpeg',
#  'Normal (142).png',
#  'Normal (1420).png',
#  'Normal (1421).png',
#  'Normal (1422).png',
#  'Normal (1423).png',
#  'Normal (1424).png',
#  'Normal (1425).png',
#  'Normal (1426).png',
#  'Normal (1427).png',
#  'Normal (1428).png',
#  'Normal (1429).png',
#  'Normal (143).jpeg',
#  'Normal (143).png',
#  'Normal (1430).png',
#  'Normal (1431).png',
#  'Normal (1432).png',
#  'Normal (1433).png',
#  'Normal (1434).png',
#  'Normal (1435).png',
#  'Normal (1436).png',
#  'Normal (1437).png',
#  'Normal (1438).png',
#  'Normal (1439).png',
#  'Normal (144).jpeg',
#  'Normal (144).png',
#  'Normal (1440).png',
#  'Normal (1441).png',
#  'Normal (1442).png',
#  'Normal (1443).png',
#  'Normal (1444).png',
#  'Normal (1445).png',
#  'Normal (1446).png',
#  'Normal (1447).png',
#  'Normal (1448).png',
#  'Normal (1449).png',
#  'Normal (145).jpeg',
#  'Normal (145).png',
#  'Normal (1450).png',
#  'Normal (1451).png',
#  'Normal (1452).png',
#  'Normal (1453).png',
#  'Normal (1454).png',
#  'Normal (1455).png',
#  'Normal (1456).png',
#  'Normal (1457).png',
#  'Normal (1458).png',
#  'Normal (1459).png',
#  'Normal (146).jpeg',
#  'Normal (146).png',
#  'Normal (1460).png',
#  'Normal (1461).png',
#  'Normal (1462).png',
#  'Normal (1463).png',
#  'Normal (1464).png',
#  'Normal (1465).png',
#  'Normal (1466).png',
#  'Normal (1467).png',
#  'Normal (1468).png',
#  'Normal (1469).png',
#  'Normal (147).jpeg',
#  'Normal (147).png',
#  'Normal (1470).png',
#  'Normal (1471).png',
#  'Normal (1472).png',
#  'Normal (1473).png',
#  'Normal (1474).png',
#  'Normal (1475).png',
#  'Normal (1476).png',
#  'Normal (1477).png',
#  'Normal (1478).png',
#  'Normal (1479).png',
#  'Normal (148).jpeg',
#  'Normal (148).png',
#  'Normal (1480).png',
#  'Normal (1481).png',
#  'Normal (1482).png',
#  'Normal (1483).png',
#  'Normal (1484).png',
#  'Normal (1485).png',
#  'Normal (1486).png',
#  'Normal (1487).png',
#  'Normal (1488).png',
#  'Normal (1489).png',
#  'Normal (149).jpeg',
#  'Normal (149).png',
#  'Normal (1490).png',
#  'Normal (1491).png',
#  'Normal (1492).png',
#  'Normal (1493).png',
#  'Normal (1494).png',
#  'Normal (1495).png',
#  'Normal (1496).png',
#  'Normal (1497).png',
#  'Normal (1498).png',
#  'Normal (1499).png',
#  'Normal (15).jpeg',
#  'Normal (15).png',
#  'Normal (150).jpeg',
#  'Normal (150).png',
#  'Normal (1500).png',
#  'Normal (1501).png',
#  'Normal (1502).png',
#  'Normal (1503).png',
#  'Normal (1504).png',
#  'Normal (1505).png',
#  'Normal (1506).png',
#  'Normal (1507).png',
#  'Normal (1508).png',
#  'Normal (1509).png',
#  'Normal (151).jpeg',
#  'Normal (151).png',
#  'Normal (1510).png',
#  'Normal (1511).png',
#  'Normal (1512).png',
#  'Normal (1513).png',
#  'Normal (1514).png',
#  'Normal (1515).png',
#  'Normal (1516).png',
#  'Normal (1517).png',
#  'Normal (1518).png',
#  'Normal (1519).png',
#  'Normal (152).jpeg',
#  'Normal (152).png',
#  'Normal (1520).png',
#  'Normal (1521).png',
#  'Normal (1522).png',
#  'Normal (1523).png',
#  'Normal (1524).png',
#  'Normal (1525).png',
#  'Normal (1526).png',
#  'Normal (1527).png',
#  'Normal (1528).png',
#  'Normal (1529).png',
#  'Normal (153).jpeg',
#  'Normal (153).png',
#  'Normal (1530).png',
#  'Normal (1531).png',
#  'Normal (1532).png',
#  'Normal (1533).png',
#  'Normal (1534).png',
#  'Normal (1535).png',
#  ...]

# %%
# val 简介
dataloaders['val'].dataset
# Out:
# Dataset ImageFolder
#     Number of datapoints: 32
#     Root location: normalViralANDbacCovid/val/
#     StandardTransform
# Transform: Compose(
#                Resize(size=300, interpolation=bilinear, max_size=None, antialias=None)
#                CenterCrop(size=(256, 256))
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %%
# test 简介
dataloaders['test'].dataset
# Out:
# Dataset ImageFolder
#     Number of datapoints: 846
#     Root location: normalViralANDbacCovid/test/
#     StandardTransform
# Transform: Compose(
#                Resize(size=300, interpolation=bilinear, max_size=None, antialias=None)
#                CenterCrop(size=(256, 256))
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %% [markdown]
# ### 提示：需要安装库：tb-nightly
# ### pip3 install tb-nightly

# %%
# 导入SummaryWriter
from torch.utils.tensorboard import SummaryWriter
# SummaryWriter() 向事件文件写入事件和概要

# 定义日志路径
log_path = 'logdir2/'

# 定义函数：获取tensorboard writer
def tb_writer():
    timestr = time.strftime("%Y%m%d_%H%M%S") # 时间格式
    writer = SummaryWriter(log_path+timestr) # 写入日志
    return writer


writer = tb_writer()

# 第1种方法：显示部分图片集
images, labels = next(iter(dataloaders['train'])) # 获取到一批数据

# 定义图片显示方法
def imshow(img):
    img = img / 2 + 0.5 # 逆正则化
    np_img = img.numpy() # tensor --> numpy
    plt.imshow(np.transpose(np_img, (1, 2, 0))) # 改变通道顺序
    plt.show()
    
grid = utils.make_grid(images) # make_grid的作用是将若干幅图像拼成一幅图像
imshow(grid) # 展示图片

# 在summary中添加图片数据
writer.add_image('X-Ray grid', grid, 0) # add_image(tag, img_tensor, global_step=None, walltime=None, dataformats='CHW')

writer.flush() # 把事件文件写入到磁盘
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# 获取一张图片tensor
dataloaders['train'].dataset[4] # 返回：tensor, label
# Out:
# (tensor([[[-0.5767, -0.5424, -0.4911,  ..., -0.9534, -0.9705, -0.9877],
#           [-0.4911, -0.4226, -0.3883,  ..., -0.9534, -0.9877, -1.0048],
#           [-0.4226, -0.3883, -0.3883,  ..., -0.9534, -0.9877, -0.9877],
#           ...,
#           [-1.3644, -1.3644, -1.3644,  ...,  0.1254,  0.0912,  0.0912],
#           [-1.3644, -1.3644, -1.3644,  ...,  0.1254,  0.0912,  0.0912],
#           [-1.3644, -1.3644, -1.3644,  ...,  0.1254,  0.1083,  0.1083]],
#
#          [[-0.4601, -0.4251, -0.3725,  ..., -0.8452, -0.8627, -0.8803],
#           [-0.3725, -0.3025, -0.2675,  ..., -0.8452, -0.8803, -0.8978],
#           [-0.3025, -0.2675, -0.2675,  ..., -0.8452, -0.8803, -0.8803],
#           ...,
#           [-1.2654, -1.2654, -1.2654,  ...,  0.2577,  0.2227,  0.2227],
#           [-1.2654, -1.2654, -1.2654,  ...,  0.2577,  0.2227,  0.2227],
#           [-1.2654, -1.2654, -1.2654,  ...,  0.2577,  0.2402,  0.2402]],
#
#          [[-0.2358, -0.2010, -0.1487,  ..., -0.6193, -0.6367, -0.6541],
#           [-0.1487, -0.0790, -0.0441,  ..., -0.6193, -0.6541, -0.6715],
#           [-0.0790, -0.0441, -0.0441,  ..., -0.6193, -0.6541, -0.6541],
#           ...,
#           [-1.0376, -1.0376, -1.0376,  ...,  0.4788,  0.4439,  0.4439],
#           [-1.0376, -1.0376, -1.0376,  ...,  0.4788,  0.4439,  0.4439],
#           [-1.0376, -1.0376, -1.0376,  ...,  0.4788,  0.4614,  0.4614]]]),
#  0)

# %%
# 第2种方法：显示一张图片
def show_sample(img, label):
    print("Label : ", dataloaders['train'].dataset.classes[label]) # 输出标签
    img = img.numpy().transpose((1, 2, 0)) # 改变shape顺序
    mean = np.array([0.485, 0.456, 0.406]) # 均值
    std = np.array([0.229, 0.224, 0.225]) # 标准差
    img = img * std + mean # 逆向复原
    img = np.clip(img, 0, 1) # np.clip() 将inp中的元素值限制在(0,1)之间，最小值为0，最大值为1。小于min的等于min，大于max等于max
    plt.imshow(img)
    plt.axis('off') # 关闭坐标轴

show_sample(*dataloaders['train'].dataset[4]) # 显示第5张图片
# Out:
# Label :  bacCovid

# %%
# 第3种方法：显示一张图片
def show_image(img):
    plt.figure(figsize=(8,8)) # 显示大小
    plt.imshow(img) # 显示图片
    plt.axis('off') # 关闭坐标轴
    plt.show()
    
# 读取图片
one_img = Image.open(dataloaders['train'].dataset.root+'bacCovid/Bacteria (1001).jpeg')

# 调用函数
show_image(one_img)

# %%
# 记录错误分类的图片
def misclassified_images(pred, writer, target, images, output, epoch, count=10):
    misclassified = (pred != target.data) # 判断是否一致
    for index, image_tensor in enumerate(images[misclassified][:count]):
        img_name = 'Epoch:{}-->Predict:{}-->Actual:{}'.format(epoch, LABEL[pred[misclassified].tolist()[index]],
                                                              LABEL[target.data[misclassified].tolist()[index]])
        writer.add_image(img_name, image_tensor, epoch)

# %%
# 自定义池化层

class AdaptiveConcatPool2d(nn.Module):
    def __init__(self, size=None):
        super(AdaptiveConcatPool2d,self).__init__()
        size = size or (1, 1) # kernel大小
        # 自适应算法能够自动帮助我们计算核的大小和每次移动的步长。
        self.avgPooling = nn.AdaptiveAvgPool2d(size) # 自适应平均池化
        self.maxPooling = nn.AdaptiveMaxPool2d(size) # 最大池化
    def forward(self, x):
        # 拼接avg和max
        return torch.cat([self.maxPooling(x), self.avgPooling(x)], dim=1)

# %%
# 迁移学习：获取预训练模型，并替换池化层和全连接层
# def get_model():
#     # 获取欲训练模型 restnet50
#     model = models.resnet50(pretrained=True) 
#     # 冻结模型参数
#     for param in model.parameters():
#         param.requires_grad = False 
#     # 替换最后2层：池化层和全连接层
#     # 池化层
#     model.avgpool = AdaptiveConcatPool2d()
#     # 全连接层
#     model.fc = nn.Sequential(
#         nn.Flatten(), # 拉平
#         nn.BatchNorm1d(4096), # 加速神经网络的收敛过程，提高训练过程中的稳定性
#         nn.Dropout(0.5), # 丢掉部分神经元
#         nn.Linear(4096, 512), # 全连接层
#         nn.ReLU(), # 激活函数
#         nn.BatchNorm1d(512), 
#         nn.Dropout(0.5),
#         nn.Linear(512, 2), # 2个输出
#         nn.LogSoftmax(dim=1) # 损失函数：将input转换成概率分布的形式，输出2个概率
#     )
#     return model
# def get_model():
#     # 使用VGG-16预训练模型
#     model = models.vgg16(pretrained=True)
#     # 冻结模型参数
#     for param in model.parameters():
#         param.requires_grad = False
#     # 替换最后两层
#     model.avgpool = AdaptiveConcatPool2d()
#     model.classifier = nn.Sequential(
#         nn.Dropout(),
#         nn.Linear(2 * 512, 256),
#         nn.ReLU(inplace=True),
#         nn.Dropout(),
#         nn.Linear(256, 4),
#         nn.LogSoftmax(dim=1)
#     )
#     return model

def get_model():
    # 获取欲训练模型 restnet50
    model = models.resnet101(pretrained=True) 
    # 冻结模型参数
    for param in model.parameters():
        param.requires_grad = False 
    # 替换最后2层：池化层和全连接层
    # 池化层
    model.avgpool = AdaptiveConcatPool2d()
    # 全连接层
    model.fc = nn.Sequential(
        nn.Flatten(), # 拉平
        nn.BatchNorm1d(4096), # 加速神经网络的收敛过程，提高训练过程中的稳定性
        nn.Dropout(0.5), # 丢掉部分神经元
        nn.Linear(4096, 512), # 全连接层
        nn.ReLU(), # 激活函数
        nn.BatchNorm1d(512), 
        nn.Dropout(0.5),
        nn.Linear(512, 2), # 2个输出
        nn.LogSoftmax(dim=1) # 损失函数：将input转换成概率分布的形式，输出2个概率
    )
    return model

# %%
# 定义训练函数
def train_val(model, device, train_loader, val_loader, optimizer, criterion, epoch, writer):
    model.train()
    total_loss = 0.0
    val_loss = 0.0
    val_acc = 0
    for batch_id, (images, labels) in enumerate(train_loader):
        # 部署到device上
        images, labels = images.to(device), labels.to(device)
        # 梯度置0
        optimizer.zero_grad()
        # 模型输出
        outputs = model(images)
        # 计算损失
        loss = criterion(outputs, labels)
        # 反向传播
        loss.backward()
        # 更新参数
        optimizer.step()
        # 累计损失
        total_loss += loss.item() * images.size(0)
    # 平均训练损失
    train_loss = total_loss / len(train_loader.dataset)
    #写入到writer中
    writer.add_scalar('Training Loss', train_loss, epoch)
    # 写入到磁盘
    writer.flush()
    
    model.eval() 
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images) # 前向传播输出
            loss = criterion(outputs, labels) # 损失
            val_loss += loss.item() * images.size(0) # 累计损失
            _, pred = torch.max(outputs, dim=1) # 获取最大概率的索引
            correct = pred.eq(labels.view_as(pred)) # 返回：tensor([ True,False,True,...,False])
            accuracy = torch.mean(correct.type(torch.FloatTensor)) # 准确率
            val_acc += accuracy.item() * images.size(0) # 累计准确率
        # 平均验证损失
        val_loss = val_loss / len(val_loader.dataset)
        # 平均准确率
        val_acc = val_acc / len(val_loader.dataset)
        
    return train_loss, val_loss, val_acc

# %%
# 定义测试函数
def test(model, device, test_loader, criterion, epoch, writer):
    model.eval()
    total_loss = 0.0
    correct = 0.0 # 正确数
    with torch.no_grad():
        for batch_id, (images, labels) in enumerate(test_loader):
            images, labels = images.to(device), labels.to(device)
            # 输出
            outputs = model(images)
            # 损失
            loss = criterion(outputs, labels)
            # 累计损失
            total_loss += loss.item()
            # 获取预测概率最大值的索引
            _, predicted = torch.max(outputs, dim=1)
            # 累计正确预测的数
            correct += predicted.eq(labels.view_as(predicted)).sum().item()
            # 错误分类的图片
            misclassified_images(predicted, writer, labels, images, outputs, epoch)
        # 平均损失
        avg_loss = total_loss / len(test_loader.dataset)
        # 计算正确率
        accuracy = 100 * correct / len(test_loader.dataset)
        # 将test的结果写入write
        writer.add_scalar("Test Loss", total_loss, epoch)
        writer.add_scalar("Accuracy", accuracy, epoch)
        writer.flush()
        return total_loss, accuracy

# %%
# 定义训练流程

# 是否有GPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print(device.type)

# 模型部署到device
model = get_model().to(device)

# 损失函数
criterion = nn.NLLLoss()

# 优化器
optimizer = optim.SGD(model.parameters(), lr=0.001)

# 定义训练流程函数
def train_epochs(model, device, dataloaders, criterion, optimizer, epochs, writer):
    # 输出信息
    print("{0:>15} | {1:>15} | {2:>15} | {3:>15} | {4:>15} | {5:>15}".format('Epoch', 'Train Loss', 'val_loss', 'val_acc', 'Test Loss', 'Test_acc'))
    # 初始最小的损失
    best_loss = np.inf
    # 开始训练、测试
    for epoch in range(epochs):
        # 训练，return: loss
        train_loss, val_loss, val_acc = train_val(model, device, dataloaders['train'], dataloaders['val'], optimizer, criterion, epoch, writer)
        # 测试，return: loss + accuracy
        test_loss, test_acc = test(model, device, dataloaders['test'], criterion, epoch, writer)
        # 判断损失是否最小
        if test_loss < best_loss:
            best_loss = test_loss # 保存最小损失
            # 保存模型
            torch.save(model.state_dict(), 'model1.pth')
        # 输出结果
        print("{0:>15} | {1:>15} | {2:>15} | {3:>15} | {4:>15} | {5:>15}".format(epoch, train_loss, val_loss, val_acc, test_loss, test_acc))
        writer.flush()
# Out:
# cpu
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet101_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet101_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# 调用函数
epochs=40
train_epochs(model, device, dataloaders, criterion, optimizer, epochs, writer)
writer.close()
# Out:
#           Epoch |      Train Loss |        val_loss |         val_acc |       Test Loss |        Test_acc
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-bd79b2cabc62> in <module>
#       1 # 调用函数
#       2 epochs=40
# ----> 3 train_epochs(model, device, dataloaders, criterion, optimizer, epochs, writer)
#       4 writer.close()
#
# <ipython-input-20-849c67685c27> in train_epochs(model, device, dataloaders, criterion, optimizer, epochs, writer)
#      24     for epoch in range(epochs):
#      25         # 训练，return: loss
# ---> 26         train_loss, val_loss, val_acc = train_val(model, device, dataloaders['train'], dataloaders['val'], optimizer, criterion, epoch, writer)
#      27         # 测试，return: loss + accuracy
#      28         test_loss, test_acc = test(model, device, dataloaders['test'], criterion, epoch, writer)
#
# <ipython-input-18-dd12fef28eb1> in train_val(model, device, train_loader, val_loader, optimizer, criterion, epoch, writer)
#       5     val_loss = 0.0
#       6     val_acc = 0
# ----> 7     for batch_id, (images, labels) in enumerate(train_loader):
#       8         # 部署到device上
#       9         images, labels = images.to(device), labels.to(device)
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     626                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     627                 self._reset()  # type: ignore[call-arg]
# --> 628             data = self._next_data()
#     629             self._num_yielded += 1
#     630             if self._dataset_kind == _DatasetKind.Iterable and \
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\utils\data\dataloader.py in _next_data(self)
#     669     def _next_data(self):
#     670         index = self._next_index()  # may raise StopIteration
# --> 671         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     672         if self._pin_memory:
#     673             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\utils\data\_utils\fetch.py in fetch(self, possibly_batched_index)
#      56                 data = self.dataset.__getitems__(possibly_batched_index)
#      57             else:
# ---> 58                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      59         else:
#      60             data = self.dataset[possibly_batched_index]
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\utils\data\_utils\fetch.py in <listcomp>(.0)
#      56                 data = self.dataset.__getitems__(possibly_batched_index)
#      57             else:
# ---> 58                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      59         else:
#      60             data = self.dataset[possibly_batched_index]
#
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\datasets\folder.py in __getitem__(self, index)
#     229         sample = self.loader(path)
#     230         if self.transform is not None:
# --> 231             sample = self.transform(sample)
#     232         if self.target_transform is not None:
#     233             target = self.target_transform(target)
#
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\transforms\transforms.py in __call__(self, img)
#      93     def __call__(self, img):
#      94         for t in self.transforms:
# ---> 95             img = t(img)
#      96         return img
#      97
#
# C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\transforms\transforms.py in forward(self, img)
#    1249                 img = F.adjust_brightness(img, brightness_factor)
#    1250             elif fn_id == 1 and contrast_factor is not None:
# -> 1251                 img = F.adjust_contrast(img, contrast_factor)
#    1252             elif fn_id == 2 and saturation_factor is not None:
#    1253                 img = F.adjust_saturation(img, saturation_factor)
#
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\transforms\functional.py in adjust_contrast(img, contrast_factor)
#     886         _log_api_usage_once(adjust_contrast)
#     887     if not isinstance(img, torch.Tensor):
# --> 888         return F_pil.adjust_contrast(img, contrast_factor)
#     889
#     890     return F_t.adjust_contrast(img, contrast_factor)
#
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\transforms\functional_pil.py in adjust_contrast(img, contrast_factor)
#      82         raise TypeError(f"img should be PIL Image. Got {type(img)}")
#      83
# ---> 84     enhancer = ImageEnhance.Contrast(img)
#      85     img = enhancer.enhance(contrast_factor)
#      86     return img
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\ImageEnhance.py in __init__(self, image)
#      65     def __init__(self, image):
#      66         self.image = image
# ---> 67         mean = int(ImageStat.Stat(image.convert("L")).mean[0] + 0.5)
#      68         self.degenerate = Image.new("L", image.size, mean).convert(image.mode)
#      69
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\ImageStat.py in __init__(self, image_or_list, mask)
#      33                 self.h = image_or_list.histogram(mask)
#      34             else:
# ---> 35                 self.h = image_or_list.histogram()
#      36         except AttributeError:
#      37             self.h = image_or_list  # assume it to be a histogram list
#
# C:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py in histogram(self, mask, extrema)
#    1419                 extrema = self.getextrema()
#    1420             return self.im.histogram(extrema)
# -> 1421         return self.im.histogram()
#    1422
#    1423     def entropy(self, mask=None, extrema=None):
#
# KeyboardInterrupt:

# %%
# import cv2


# # 定义 Grad-CAM 类
# class GradCAM:
#     def __init__(self, model, target_layer):
#         self.model = model
#         self.target_layer = target_layer
#         self.feature_maps = None
#         self.gradient = None

#     def save_gradient(self, gradient):
#         self.gradient = gradient
        
#     def __call__(self, input):
#         # 调整维度
#         input = input.squeeze(0)
#         input = torch.transpose(input, 0, 1)

#         # 前向传播，记录目标层的特征图
#         for name, module in self.model.named_modules():
#             input = module(input)
#             if name == self.target_layer:
#                 input.register_hook(self.save_gradient)
#                 self.feature_maps = input.detach()
#         output = input

#         # 反向传播，计算梯度
#         output.backward(torch.ones_like(output))
#         # 计算梯度加权特征图
#         gradients = self.gradient.detach().cpu().numpy()[0]
#         weights = np.mean(gradients, axis=(1, 2), keepdims=True)
#         cam = np.sum(weights * self.feature_maps.cpu().numpy()[0], axis=0)
#         cam = np.maximum(cam, 0)  # ReLU
#         cam = cv2.resize(cam, input.shape[1:])  # 调整特征图尺寸
#         cam = cam - np.min(cam)  # 线性规范化
#         cam = cam / np.max(cam)

#         return cam


#     def __call__(self, x):
#         # 前向传播，记录目标层的特征图
#         for name, module in self.model.named_modules():
#             x = module(x)
#             if name == self.target_layer:
#                 x.register_hook(self.save_gradient)
#                 self.feature_maps = x.detach()
#         output = x
#         # 反向传播，计算梯度
#         output.backward(torch.ones_like(output))
#         # 计算梯度加权特征图
#         gradients = self.gradient.detach().cpu().numpy()[0]
#         weights = np.mean(gradients, axis=(1, 2), keepdims=True)
#         cam = np.sum(weights * self.feature_maps.cpu().numpy()[0], axis=0)
#         cam = np.maximum(cam, 0)  # ReLU
#         cam = cv2.resize(cam, x.shape[2:])  # 调整特征图尺寸
#         cam = cam - np.min(cam)  # 线性规范化
#         cam = cam / np.max(cam)
#         return cam

# 获取模型
# model = get_model()
# # 加载预训练权重
# model.load_state_dict(torch.load('model2.pth', map_location=torch.device('cpu')))
# # 设置为评估模式
# model.eval()
# # 定义 Grad-CAM 对象
# grad_cam = GradCAM(model, 'layer4') # 这里选择 ResNet50 的 layer4 层作为目标层

# # 加载目标图像并预处理
# image = cv2.imread('newDataset_binary/train/BacterialPneumonia/101.jpeg')
# image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
# image = cv2.resize(image, (224, 224))
# image = image / 255.
# image = (image - [0.485, 0.456, 0.406]) / [0.229, 0.224, 0.225]
# image = np.transpose(image, (2, 0, 1))
# image = np.expand_dims(image, axis=0)
# image = torch.from_numpy(image).float()

# # 使用 Grad-CAM 进行可视化
# with torch.set_grad_enabled(True):
#     output = model(image)
#     _, pred = output.max(dim=1)
#     cam = grad_cam(image)
#     cam = cv2.resize(cam, (224, 224))
#     heatmap = cv2.applyColorMap(np.uint8(255*cam), cv2.COLORMAP_JET)
#     heatmap = np.float32(heatmap) / 255
#     cam_on_image = heatmap + np.float32(cv2.cvtColor(np.uint8(255*image[0].permute(1,2,0).cpu().numpy()), cv2.COLOR_BGR2RGB))
#     cam_on_image = cam_on_image / np.max(cam_on_image)

# # 显示结果
# import matplotlib.pyplot as plt
# plt.imshow(cam_on_image)
# plt.axis('off')
# plt.show()

# %%
# import cv2
# import numpy as np
# import torch
# from torchvision import models, transforms
# from torch.nn import functional as F
# from matplotlib import pyplot as plt

# # 定义Grad-CAM可视化函数
# class GradCam:
#     def __init__(self, model, target_layer_names):
#         self.model = model
#         self.target_layer_names = target_layer_names
#         self.feature_maps = []
#         self.gradient_maps = []
#         self.model.eval()
#         self.handlers = []
#         for name in self.target_layer_names:
#             self.handlers.append(
#                 self.register_hook(self.model._modules.get(name))
#             )

#     def register_hook(self, module):
#         def hook(module, input, output):
#             self.feature_maps.append(output.cpu().data.numpy())

#         return module.register_forward_hook(hook)

#     def remove_handlers(self):
#         for handle in self.handlers:
#             handle.remove()

#     def __call__(self, x):
#         self.feature_maps = []
#         self.gradient_maps = []
#         self.handlers = []
#         for name in self.target_layer_names:
#             self.handlers.append(
#                 self.register_hook(self.model._modules.get(name))
#             )

#         outputs = self.model(x)
#         one_hot = outputs.detach().zero_()
#         one_hot[0][torch.argmax(outputs)] = 1
#         one_hot.requires_grad = True
#         one_hot = torch.sum(one_hot * outputs)

#         self.model.zero_grad()
#         one_hot.backward(retain_graph=True)

#         self.gradient_maps = []
#         for i, name in enumerate(self.target_layer_names):
#             gradient_map = (
#                 self.feature_maps[i][0] * self.gradient_maps[-1]
#                 if len(self.gradient_maps) > 0
#                 else self.feature_maps[i][0]
#             )
#             self.gradient_maps.append(gradient_map)

#         self.remove_handlers()
#         return self.gradient_maps[-1]

# # 定义输入图像预处理函数
# def preprocess_image(img_path):
#     img = cv2.imread(img_path)
#     img = cv2.resize(img, (224, 224))
#     img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#     img_tensor = transforms.ToTensor()(img)
#     img_tensor = transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])(img_tensor)
#     img_tensor = img_tensor.unsqueeze(0)
#     return img_tensor

# # 加载模型
# model = get_model()
# # 加载图像
# img_tensor = preprocess_image('newDataset_binary/train/BacterialPneumonia/101.jpeg')
# # 运行Grad-CAM可视化
# torch.autograd.set_detect_anomaly(True)
# cam = GradCam(model, ['layer4'])
# grad_cam = cam(img_tensor)
# # 将可视化结果转换为热力图
# grad_cam = np.mean(grad_cam, axis=(1, 2), keepdims=True)
# grad_cam = np.maximum(grad_cam, 0)
# grad_cam = grad_cam / grad_cam.max()
# # 将热力图叠加到原始图像上
# img = cv2.imread(dataloaders['train'].dataset.root+'BacterialPneumonia/101.jpeg')
# grad_cam = cv2.resize(grad_cam[0], (img.shape[1], img.shape[0]))
# grad_cam = cv2.applyColorMap(np.uint8(255 * grad_cam), cv2.COLORMAP_JET)
# output_image = cv2.addWeighted(img, 0.8, grad_cam, 0.4, 0)
# # 显示结果
# plt.imshow(output_image[...,::-1])
# plt.axis('off')
# plt

# %%
def plot_confusion(cm):
    plt.figure()
    plot_confusion_matrix(cm, figsize=(12, 8), cmap=plt.cm.Blues) # 参数设置
    plt.xticks(range(2), ['bacCovid', 'normalViral'], fontsize=14)
    plt.yticks(range(2), ['bacCovid', 'normalViral''], fontsize=14)
    plt.xlabel('Predicted Label', fontsize=16)
    plt.ylabel('True Label', fontsize=16)
    plt.show()

# %%
# def accuracy(outputs, labels):
#     # 计算正确率
#     _, preds = torch.max(outputs, dim=1)
#     correct = torch.tensor(torch.sum(preds == labels).item() / len(preds))
#     return correct

# %%
# def metrics(outputs, labels):
#     _, preds = torch.max(outputs, dim=1)
#     # precision, recall, F1
#     # 混淆矩阵
#     cm = confusion_matrix(labels.cpu().numpy(), preds.cpu().numpy())
#     # 绘制混淆矩阵
#     plot_confusion(cm) 
#     # 获取tn, fp, fn, tp
# #     tn, fp, fn, tp = cm.ravel()
#     fp = cm.sum(axis=0) - np.diag(cm)
#     fn = cm.sum(axis=1) - np.diag(cm)
#     tp = np.diag(cm)
#     tn = cm.sum() - (fp + fn + tp)
#     print(tn)
#     print(fp)
#     # 精准率
#     precision = tp / (tp + fp)
#     # 召回率
#     recall = tp / (tp + fn)
#     # f1 score
#     f1 = 2 * ((precision * recall) / (precision + recall))
#     return precision, recall, f1

# %%
all_preds = []
all_labels = []

with torch.no_grad():
    model.eval()
    for datas, labels in dataloaders['test']:
        datas, labels = datas.to(device), labels.to(device)
        # 预测输出 前向传播
        outputs = model(datas)
        _, preds = torch.max(outputs, dim=1)
#     将预测结果和真实标签添加到列表中
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
        # precision, recall, F1
        # 混淆矩阵
    cm = confusion_matrix(all_labels, all_preds)
    # 绘制混淆矩阵
    plot_confusion(cm) 
#     fp = cm.sum(axis=0) - np.diag(cm)
#     fn = cm.sum(axis=1) - np.diag(cm)
#     tp = np.diag(cm)
#     tn = cm.sum() - (fp + fn + tp)
    tn, fp, fn, tp = cm.ravel()
    # 精准率
    precision = tp / (tp + fp)
    # 召回率
    recall = tp / (tp + fn)
    # f1 score
    f1 = 2 * ((precision * recall) / (precision + recall))
    num_correct = 0
    num_total = len(all_labels)
    for pred, label in zip(all_preds, all_labels):
        if pred == label:
            num_correct += 1
            acc = num_correct / num_total
#     acc = torch.tensor(torch.sum(all_preds == all_labels.data).item() / len(all_preds))
    print(precision)
    print(recall)
    print(f1)
    print(acc)

# with torch.no_grad():
#     model.eval()
#     for datas, labels in dataloaders['val']:
#         datas, labels = datas.to(device), labels.to(device)
#         # 预测输出
#         outputs = model(datas)
#         # 计算metrics
#         precision, recall, f1 = metrics(outputs, labels)
#         acc = accuracy(outputs, labels)
#         # 保存结果
#         precisions.append(precision)
#         recalls.append(recall)
#         f1s.append(f1)
#         accuracies.append(acc.item())
#         print(precisions)
#         print(recalls)

# %%
# ['{:.2f}%'.format(pre*100) for pre in precisions]# 精准率 precision

# %%
# ['{:.2f}%'.format(r*100) for r in recalls]# 召回率 recall

# %%
# ['{:.2f}%'.format(f*100) for f in f1s]# f1

# %%
# ['{:.2f}%'.format(a*100) for a in accuracies]# 准确率 accuracy
